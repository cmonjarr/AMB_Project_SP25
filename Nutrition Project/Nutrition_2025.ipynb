# %% [markdown]
# ## **A comparison of nutrition information from two popular quick-service restaurants: Starbucks & McDonald's**

# %% [markdown]
# ## Abstract
#
# An analysis of nutrition facts for two popular quick-service restaurants, **Starbucks (SBUX)** and **McDonald’s (MCD)** to delineate comparative values for *macronutrients (macros)* such as fats, carbohydrates, and proteins.

# %% [markdown]
# ## Problem Overview
#
# #### **Problem statement:**
#
# Ever see these logos while driving to work?
# ![Image](https://cdn.apartmenttherapy.info/image/upload/f_auto,q_auto:eco,c_fit,w_730,h_488/at%2Farchive%2F2a2e07e47ac11c41e3ef81fb9fb76a7ee9f1634b)
#
# ![Image](https://www.designyourway.net/blog/wp-content/uploads/2023/06/Featured-1-14.jpg)
#
#
# Despite becoming increasingly health conscious, Americans continue to frequent quick-service restaurants on a regular basis. While nutrition facts are ubiquitously available, they may not be frequently reviewed.
#
#  With restaurants being categorized into fast food versus fast casual versus coffee shops, this comparative analysis aims to assess for variations in the nutritional makeup of items sold at two common quick-service restaurants. Is one location more nutritious than the other?

# %% [markdown]
# **Objectives**:
#
# - To determine if there is variation in the macronutient nutritional makeup (macros) of items at SBUX versus MCD.
# - To determine patterns in macros by 1-item type, 2-restaurant.

# %% [markdown]
# **Data sources**:
#
# Following extensive topic review, the following two datasets were idenitified using a "nutrition" search in kaggle: [Starbuck's Nutrition Facts](https://www.kaggle.com/datasets/starbucks/starbucks-menu) and [McDonald's Nutriction Facts](https://www.kaggle.com/datasets/mcdonalds/nutrition-facts).

# %% [markdown]
# ## Advisory Statement
#
# To help users follow along, additional markdown headers have been included for clarity.
#
# *Advanced users may wish to skip these additions and can proceed directly to review of code if preferred*.

# %% [markdown]
# ## Data Libraries, Collection, and Loading
#
# ### **Installing Data Libraries**
#
# Steps to installing Data Libraries include:
#
# 1. The following libraries were installed to the virtual environment using the *pip install* command.
#
# 2. The *pip list* command can be used to verify the these libraries were correctly installed in the virtual environment.
#
# The above steps are important to ensure that these libraries will be available for the following lines of code.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### **Data Collection & Loading**
#
# #### **Loading data**:
#
# Pandas was utilized to load the CSV data files.

# %%
# loading dataset files to an original dataframe (helpful in case backup needed)
sbux = pd.read_csv("SBUXmenu.csv", index_col = "Beverage")
mcd  = pd.read_csv("mcdmenu.csv", index_col = "Item")

# %% [markdown]
# #### **Initial data check**:
#
# Display the first few or last rows and basic information about the dataset, noting column names, types, and missing values.

# %% [markdown]
# #### Shape:

# %% [markdown]
# Displaying # of columns and rows in abbrevated and sentence form.

# %%
# displaying the dimensions of the SBUX DataFrame (ie # of rows & # of columns in the dataset)
sbux.shape
# Out:
# (242, 17)

# %%
# converting SBUX dataframe dimension info into a sentence format
df_shape = sbux.shape
print(f"The SBUX DataFrame has {df_shape[0]} rows and {df_shape[1]} columns.")
# Out:
# The SBUX DataFrame has 242 rows and 17 columns.

# %%
# displaying the dimensions of the MCD DataFrame (ie # of rows & # of columns in the dataset)
mcd.shape
# Out:
# (260, 23)

# %%
# converting MCD dataframe dimension info into a sentence format
df_shape = mcd.shape
print(f"The MCD DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The MCD DataFrame has 260 rows and 23 columns!

# %% [markdown]
# #### Head

# %% [markdown]
# Displaying heads (beginning) of dataframe.
#
# Using parenthesis allows for setting how many rows will be displayed.

# %%
# displaying the first 15 rows of the dataframe
sbux.head(15)
# Out:
#                      Beverage_category       Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                   Coffee               Short         3
# Brewed Coffee                   Coffee                Tall         4
# Brewed Coffee                   Coffee              Grande         5
# Brewed Coffee                   Coffee               Venti         5
# Caffè Latte    Classic Espresso Drinks   Short Nonfat Milk        70
# Caffè Latte    Classic Espresso Drinks             2% Milk       100
# Caffè Latte    Classic Espresso Drinks             Soymilk        70
# Caffè Latte    Classic Espresso Drinks    Tall Nonfat Milk       100
# Caffè Latte    Classic Espresso Drinks             2% Milk       150
# Caffè Latte    Classic Espresso Drinks             Soymilk       110
# Caffè Latte    Classic Espresso Drinks  Grande Nonfat Milk       130
# Caffè Latte    Classic Espresso Drinks             2% Milk       190
# Caffè Latte    Classic Espresso Drinks             Soymilk       150
# Caffè Latte    Classic Espresso Drinks   Venti Nonfat Milk       170
# Caffè Latte    Classic Espresso Drinks             2% Milk       240
#
#                Total Fat (g)  Trans Fat (g)   Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee            0.1            0.00               0.00             0
# Brewed Coffee            0.1            0.00               0.00             0
# Brewed Coffee            0.1            0.00               0.00             0
# Brewed Coffee            0.1            0.00               0.00             0
# Caffè Latte              0.1            0.10               0.00             5
# Caffè Latte              3.5            2.00               0.10            15
# Caffè Latte              2.5            0.40               0.00             0
# Caffè Latte              0.2            0.20               0.00             5
# Caffè Latte                6            3.00               0.20            25
# Caffè Latte              4.5            0.50               0.00             0
# Caffè Latte              0.3            0.20               0.00             5
# Caffè Latte                7            3.50               0.20            30
# Caffè Latte                5            0.50               0.00             0
# Caffè Latte              0.4            0.30               0.00            10
# Caffè Latte                9            4.50               0.30            35
#
#                 Total Carbohydrates (g)   Cholesterol (mg)  \
# Beverage
# Brewed Coffee                          5                 0
# Brewed Coffee                         10                 0
# Brewed Coffee                         10                 0
# Brewed Coffee                         10                 0
# Caffè Latte                           75                10
# Caffè Latte                           85                10
# Caffè Latte                           65                 6
# Caffè Latte                          120                15
# Caffè Latte                          135                15
# Caffè Latte                          105                10
# Caffè Latte                          150                19
# Caffè Latte                          170                19
# Caffè Latte                          130                13
# Caffè Latte                          190                25
# Caffè Latte                          220                24
#
#                 Dietary Fibre (g)   Sugars (g)   Protein (g)   \
# Beverage
# Brewed Coffee                   0            0           0.30
# Brewed Coffee                   0            0           0.50
# Brewed Coffee                   0            0           1.00
# Brewed Coffee                   0            0           1.00
# Caffè Latte                     0            9           6.00
# Caffè Latte                     0            9           6.00
# Caffè Latte                     1            4           5.00
# Caffè Latte                     0           14          10.00
# Caffè Latte                     0           14          10.00
# Caffè Latte                     1            6           8.00
# Caffè Latte                     0           18          13.00
# Caffè Latte                     0           17          12.00
# Caffè Latte                     1            8          10.00
# Caffè Latte                     0           23          16.00
# Caffè Latte                     0           22          16.00
#
#               Vitamin A (% DV)  Vitamin C (% DV)  Calcium (% DV)   \
# Beverage
# Brewed Coffee                0%               0%               0%
# Brewed Coffee                0%               0%               0%
# Brewed Coffee                0%               0%               0%
# Brewed Coffee                0%               0%               2%
# Caffè Latte                 10%               0%              20%
# Caffè Latte                 10%               0%              20%
# Caffè Latte                  6%               0%              20%
# Caffè Latte                 15%               0%              30%
# Caffè Latte                 15%               0%              30%
# Caffè Latte                 10%               0%              30%
# Caffè Latte                 20%               0%              40%
# Caffè Latte                 20%               2%              40%
# Caffè Latte                 15%               0%              40%
# Caffè Latte                 30%               0%              50%
# Caffè Latte                 25%               2%              50%
#
#               Iron (% DV)  Caffeine (mg)
# Beverage
# Brewed Coffee           0%           175
# Brewed Coffee           0%           260
# Brewed Coffee           0%           330
# Brewed Coffee           0%           410
# Caffè Latte             0%            75
# Caffè Latte             0%            75
# Caffè Latte             8%            75
# Caffè Latte             0%            75
# Caffè Latte             0%            75
# Caffè Latte            15%            75
# Caffè Latte             0%           150
# Caffè Latte             0%           150
# Caffè Latte            15%           150
# Caffè Latte             0%           150
# Caffè Latte             0%           150

# %%
mcd.head(15)
# Out:
#                                                      Category    Serving Size  \
# Item
# Egg McMuffin                                        Breakfast  4.8 oz (136 g)
# Egg White Delight                                   Breakfast  4.8 oz (135 g)
# Sausage McMuffin                                    Breakfast  3.9 oz (111 g)
# Sausage McMuffin with Egg                           Breakfast  5.7 oz (161 g)
# Sausage McMuffin with Egg Whites                    Breakfast  5.7 oz (161 g)
# Steak & Egg McMuffin                                Breakfast  6.5 oz (185 g)
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)       Breakfast  5.3 oz (150 g)
# Bacon, Egg & Cheese Biscuit (Large Biscuit)         Breakfast  5.8 oz (164 g)
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...  Breakfast  5.4 oz (153 g)
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...  Breakfast  5.9 oz (167 g)
# Sausage Biscuit (Regular Biscuit)                   Breakfast  4.1 oz (117 g)
# Sausage Biscuit (Large Biscuit)                     Breakfast  4.6 oz (131 g)
# Sausage Biscuit with Egg (Regular Biscuit)          Breakfast  5.7 oz (163 g)
# Sausage Biscuit with Egg (Large Biscuit)            Breakfast  6.2 oz (177 g)
# Sausage Biscuit with Egg Whites (Regular Biscuit)   Breakfast  5.9 oz (167 g)
#
#                                                     Calories  \
# Item
# Egg McMuffin                                             300
# Egg White Delight                                        250
# Sausage McMuffin                                         370
# Sausage McMuffin with Egg                                450
# Sausage McMuffin with Egg Whites                         400
# Steak & Egg McMuffin                                     430
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)            460
# Bacon, Egg & Cheese Biscuit (Large Biscuit)              520
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...       410
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...       470
# Sausage Biscuit (Regular Biscuit)                        430
# Sausage Biscuit (Large Biscuit)                          480
# Sausage Biscuit with Egg (Regular Biscuit)               510
# Sausage Biscuit with Egg (Large Biscuit)                 570
# Sausage Biscuit with Egg Whites (Regular Biscuit)        460
#
#                                                     Calories from Fat  \
# Item
# Egg McMuffin                                                      120
# Egg White Delight                                                  70
# Sausage McMuffin                                                  200
# Sausage McMuffin with Egg                                         250
# Sausage McMuffin with Egg Whites                                  210
# Steak & Egg McMuffin                                              210
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                     230
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                       270
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                180
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                220
# Sausage Biscuit (Regular Biscuit)                                 240
# Sausage Biscuit (Large Biscuit)                                   280
# Sausage Biscuit with Egg (Regular Biscuit)                        290
# Sausage Biscuit with Egg (Large Biscuit)                          330
# Sausage Biscuit with Egg Whites (Regular Biscuit)                 250
#
#                                                     Total Fat  \
# Item
# Egg McMuffin                                            13.00
# Egg White Delight                                        8.00
# Sausage McMuffin                                        23.00
# Sausage McMuffin with Egg                               28.00
# Sausage McMuffin with Egg Whites                        23.00
# Steak & Egg McMuffin                                    23.00
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)           26.00
# Bacon, Egg & Cheese Biscuit (Large Biscuit)             30.00
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...      20.00
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...      25.00
# Sausage Biscuit (Regular Biscuit)                       27.00
# Sausage Biscuit (Large Biscuit)                         31.00
# Sausage Biscuit with Egg (Regular Biscuit)              33.00
# Sausage Biscuit with Egg (Large Biscuit)                37.00
# Sausage Biscuit with Egg Whites (Regular Biscuit)       27.00
#
#                                                     Total Fat (% Daily Value)  \
# Item
# Egg McMuffin                                                               20
# Egg White Delight                                                          12
# Sausage McMuffin                                                           35
# Sausage McMuffin with Egg                                                  43
# Sausage McMuffin with Egg Whites                                           35
# Steak & Egg McMuffin                                                       36
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                              40
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                47
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                         32
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                         38
# Sausage Biscuit (Regular Biscuit)                                          42
# Sausage Biscuit (Large Biscuit)                                            48
# Sausage Biscuit with Egg (Regular Biscuit)                                 50
# Sausage Biscuit with Egg (Large Biscuit)                                   57
# Sausage Biscuit with Egg Whites (Regular Biscuit)                          42
#
#                                                     Saturated Fat  \
# Item
# Egg McMuffin                                                 5.00
# Egg White Delight                                            3.00
# Sausage McMuffin                                             8.00
# Sausage McMuffin with Egg                                   10.00
# Sausage McMuffin with Egg Whites                             8.00
# Steak & Egg McMuffin                                         9.00
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)               13.00
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                 14.00
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...          11.00
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...          12.00
# Sausage Biscuit (Regular Biscuit)                           12.00
# Sausage Biscuit (Large Biscuit)                             13.00
# Sausage Biscuit with Egg (Regular Biscuit)                  14.00
# Sausage Biscuit with Egg (Large Biscuit)                    15.00
# Sausage Biscuit with Egg Whites (Regular Biscuit)           12.00
#
#                                                     Saturated Fat (% Daily Value)  \
# Item
# Egg McMuffin                                                                   25
# Egg White Delight                                                              15
# Sausage McMuffin                                                               42
# Sausage McMuffin with Egg                                                      52
# Sausage McMuffin with Egg Whites                                               42
# Steak & Egg McMuffin                                                           46
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                                  65
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                    68
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                             56
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                             59
# Sausage Biscuit (Regular Biscuit)                                              62
# Sausage Biscuit (Large Biscuit)                                                65
# Sausage Biscuit with Egg (Regular Biscuit)                                     71
# Sausage Biscuit with Egg (Large Biscuit)                                       74
# Sausage Biscuit with Egg Whites (Regular Biscuit)                              62
#
#                                                     Trans Fat  Cholesterol  \
# Item
# Egg McMuffin                                             0.00          260
# Egg White Delight                                        0.00           25
# Sausage McMuffin                                         0.00           45
# Sausage McMuffin with Egg                                0.00          285
# Sausage McMuffin with Egg Whites                         0.00           50
# Steak & Egg McMuffin                                     1.00          300
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)            0.00          250
# Bacon, Egg & Cheese Biscuit (Large Biscuit)              0.00          250
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...       0.00           35
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...       0.00           35
# Sausage Biscuit (Regular Biscuit)                        0.00           30
# Sausage Biscuit (Large Biscuit)                          0.00           30
# Sausage Biscuit with Egg (Regular Biscuit)               0.00          250
# Sausage Biscuit with Egg (Large Biscuit)                 0.00          250
# Sausage Biscuit with Egg Whites (Regular Biscuit)        0.00           35
#
#                                                     ...  Carbohydrates  \
# Item                                                ...
# Egg McMuffin                                        ...             31
# Egg White Delight                                   ...             30
# Sausage McMuffin                                    ...             29
# Sausage McMuffin with Egg                           ...             30
# Sausage McMuffin with Egg Whites                    ...             30
# Steak & Egg McMuffin                                ...             31
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)       ...             38
# Bacon, Egg & Cheese Biscuit (Large Biscuit)         ...             43
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...  ...             36
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...  ...             42
# Sausage Biscuit (Regular Biscuit)                   ...             34
# Sausage Biscuit (Large Biscuit)                     ...             39
# Sausage Biscuit with Egg (Regular Biscuit)          ...             36
# Sausage Biscuit with Egg (Large Biscuit)            ...             42
# Sausage Biscuit with Egg Whites (Regular Biscuit)   ...             34
#
#                                                     Carbohydrates (% Daily Value)  \
# Item
# Egg McMuffin                                                                   10
# Egg White Delight                                                              10
# Sausage McMuffin                                                               10
# Sausage McMuffin with Egg                                                      10
# Sausage McMuffin with Egg Whites                                               10
# Steak & Egg McMuffin                                                           10
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                                  13
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                    14
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                             12
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                             14
# Sausage Biscuit (Regular Biscuit)                                              11
# Sausage Biscuit (Large Biscuit)                                                13
# Sausage Biscuit with Egg (Regular Biscuit)                                     12
# Sausage Biscuit with Egg (Large Biscuit)                                       14
# Sausage Biscuit with Egg Whites (Regular Biscuit)                              11
#
#                                                     Dietary Fiber  \
# Item
# Egg McMuffin                                                    4
# Egg White Delight                                               4
# Sausage McMuffin                                                4
# Sausage McMuffin with Egg                                       4
# Sausage McMuffin with Egg Whites                                4
# Steak & Egg McMuffin                                            4
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                   2
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                     3
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...              2
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...              3
# Sausage Biscuit (Regular Biscuit)                               2
# Sausage Biscuit (Large Biscuit)                                 3
# Sausage Biscuit with Egg (Regular Biscuit)                      2
# Sausage Biscuit with Egg (Large Biscuit)                        3
# Sausage Biscuit with Egg Whites (Regular Biscuit)               2
#
#                                                     Dietary Fiber (% Daily Value)  \
# Item
# Egg McMuffin                                                                   17
# Egg White Delight                                                              17
# Sausage McMuffin                                                               17
# Sausage McMuffin with Egg                                                      17
# Sausage McMuffin with Egg Whites                                               17
# Steak & Egg McMuffin                                                           18
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                                   7
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                    12
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                              7
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                             12
# Sausage Biscuit (Regular Biscuit)                                               6
# Sausage Biscuit (Large Biscuit)                                                11
# Sausage Biscuit with Egg (Regular Biscuit)                                      6
# Sausage Biscuit with Egg (Large Biscuit)                                       11
# Sausage Biscuit with Egg Whites (Regular Biscuit)                               6
#
#                                                     Sugars  Protein  \
# Item
# Egg McMuffin                                             3       17
# Egg White Delight                                        3       18
# Sausage McMuffin                                         2       14
# Sausage McMuffin with Egg                                2       21
# Sausage McMuffin with Egg Whites                         2       21
# Steak & Egg McMuffin                                     3       26
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)            3       19
# Bacon, Egg & Cheese Biscuit (Large Biscuit)              4       19
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...       3       20
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...       4       20
# Sausage Biscuit (Regular Biscuit)                        2       11
# Sausage Biscuit (Large Biscuit)                          3       11
# Sausage Biscuit with Egg (Regular Biscuit)               2       18
# Sausage Biscuit with Egg (Large Biscuit)                 3       18
# Sausage Biscuit with Egg Whites (Regular Biscuit)        3       18
#
#                                                     Vitamin A (% Daily Value)  \
# Item
# Egg McMuffin                                                               10
# Egg White Delight                                                           6
# Sausage McMuffin                                                            8
# Sausage McMuffin with Egg                                                  15
# Sausage McMuffin with Egg Whites                                            6
# Steak & Egg McMuffin                                                       15
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                              10
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                15
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                          2
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                          6
# Sausage Biscuit (Regular Biscuit)                                           0
# Sausage Biscuit (Large Biscuit)                                             4
# Sausage Biscuit with Egg (Regular Biscuit)                                  6
# Sausage Biscuit with Egg (Large Biscuit)                                   10
# Sausage Biscuit with Egg Whites (Regular Biscuit)                           0
#
#                                                     Vitamin C (% Daily Value)  \
# Item
# Egg McMuffin                                                                0
# Egg White Delight                                                           0
# Sausage McMuffin                                                            0
# Sausage McMuffin with Egg                                                   0
# Sausage McMuffin with Egg Whites                                            0
# Steak & Egg McMuffin                                                        2
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                               8
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                                 8
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                          8
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                          8
# Sausage Biscuit (Regular Biscuit)                                           0
# Sausage Biscuit (Large Biscuit)                                             0
# Sausage Biscuit with Egg (Regular Biscuit)                                  0
# Sausage Biscuit with Egg (Large Biscuit)                                    0
# Sausage Biscuit with Egg Whites (Regular Biscuit)                           0
#
#                                                     Calcium (% Daily Value)  \
# Item
# Egg McMuffin                                                             25
# Egg White Delight                                                        25
# Sausage McMuffin                                                         25
# Sausage McMuffin with Egg                                                30
# Sausage McMuffin with Egg Whites                                         25
# Steak & Egg McMuffin                                                     30
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                            15
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                              20
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                       15
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                       15
# Sausage Biscuit (Regular Biscuit)                                         6
# Sausage Biscuit (Large Biscuit)                                           8
# Sausage Biscuit with Egg (Regular Biscuit)                               10
# Sausage Biscuit with Egg (Large Biscuit)                                 10
# Sausage Biscuit with Egg Whites (Regular Biscuit)                         8
#
#                                                     Iron (% Daily Value)
# Item
# Egg McMuffin                                                          15
# Egg White Delight                                                      8
# Sausage McMuffin                                                      10
# Sausage McMuffin with Egg                                             15
# Sausage McMuffin with Egg Whites                                      10
# Steak & Egg McMuffin                                                  20
# Bacon, Egg & Cheese Biscuit (Regular Biscuit)                         15
# Bacon, Egg & Cheese Biscuit (Large Biscuit)                           20
# Bacon, Egg & Cheese Biscuit with Egg Whites (Re...                    10
# Bacon, Egg & Cheese Biscuit with Egg Whites (La...                    15
# Sausage Biscuit (Regular Biscuit)                                     15
# Sausage Biscuit (Large Biscuit)                                       15
# Sausage Biscuit with Egg (Regular Biscuit)                            20
# Sausage Biscuit with Egg (Large Biscuit)                              20
# Sausage Biscuit with Egg Whites (Regular Biscuit)                     15
#
# [15 rows x 23 columns]

# %% [markdown]
# #### Quick Dataframe Overviews (in Jupyter Notebooks only)

# %% [markdown]
# Displaying formatted quick overviews of the dataframes.

# %%
# displaying data in a formatted quick overview of the DataFrame structure
# if not using a jupyter notebook, would need to use: print(variable nam
# e)
sbux
# Out:
#                                                        Beverage_category  \
# Beverage
# Brewed Coffee                                                     Coffee
# Brewed Coffee                                                     Coffee
# Brewed Coffee                                                     Coffee
# Brewed Coffee                                                     Coffee
# Caffè Latte                                      Classic Espresso Drinks
# ...                                                                  ...
# Strawberries & Crème (Without Whipped Cream)  Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)          Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)          Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)          Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)          Frappuccino® Blended Crème
#
#                                                    Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                                              Short         3
# Brewed Coffee                                               Tall         4
# Brewed Coffee                                             Grande         5
# Brewed Coffee                                              Venti         5
# Caffè Latte                                    Short Nonfat Milk        70
# ...                                                          ...       ...
# Strawberries & Crème (Without Whipped Cream)             Soymilk       320
# Vanilla Bean (Without Whipped Cream)            Tall Nonfat Milk       170
# Vanilla Bean (Without Whipped Cream)                  Whole Milk       200
# Vanilla Bean (Without Whipped Cream)                     Soymilk       180
# Vanilla Bean (Without Whipped Cream)          Grande Nonfat Milk       240
#
#                                               Total Fat (g)  Trans Fat (g)   \
# Beverage
# Brewed Coffee                                           0.1            0.00
# Brewed Coffee                                           0.1            0.00
# Brewed Coffee                                           0.1            0.00
# Brewed Coffee                                           0.1            0.00
# Caffè Latte                                             0.1            0.10
# ...                                                     ...             ...
# Strawberries & Crème (Without Whipped Cream)            3 2            0.40
# Vanilla Bean (Without Whipped Cream)                    0.1            0.10
# Vanilla Bean (Without Whipped Cream)                    3.5            2.00
# Vanilla Bean (Without Whipped Cream)                    1.5            0.20
# Vanilla Bean (Without Whipped Cream)                    0.1            0.10
#
#                                               Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee                                              0.00             0
# Brewed Coffee                                              0.00             0
# Brewed Coffee                                              0.00             0
# Brewed Coffee                                              0.00             0
# Caffè Latte                                                0.00             5
# ...                                                         ...           ...
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.10            10
# Vanilla Bean (Without Whipped Cream)                       0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.00             5
#
#                                                Total Carbohydrates (g)   \
# Beverage
# Brewed Coffee                                                         5
# Brewed Coffee                                                        10
# Brewed Coffee                                                        10
# Brewed Coffee                                                        10
# Caffè Latte                                                          75
# ...                                                                 ...
# Strawberries & Crème (Without Whipped Cream)                        250
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                230
#
#                                               Cholesterol (mg)  \
# Beverage
# Brewed Coffee                                                0
# Brewed Coffee                                                0
# Brewed Coffee                                                0
# Brewed Coffee                                                0
# Caffè Latte                                                 10
# ...                                                        ...
# Strawberries & Crème (Without Whipped Cream)                67
# Vanilla Bean (Without Whipped Cream)                        39
# Vanilla Bean (Without Whipped Cream)                        39
# Vanilla Bean (Without Whipped Cream)                        37
# Vanilla Bean (Without Whipped Cream)                        56
#
#                                                Dietary Fibre (g)   Sugars (g)  \
# Beverage
# Brewed Coffee                                                  0            0
# Brewed Coffee                                                  0            0
# Brewed Coffee                                                  0            0
# Brewed Coffee                                                  0            0
# Caffè Latte                                                    0            9
# ...                                                          ...          ...
# Strawberries & Crème (Without Whipped Cream)                   1           64
# Vanilla Bean (Without Whipped Cream)                           0           38
# Vanilla Bean (Without Whipped Cream)                           0           38
# Vanilla Bean (Without Whipped Cream)                           1           35
# Vanilla Bean (Without Whipped Cream)                           0           55
#
#                                                Protein (g)  Vitamin A (% DV)   \
# Beverage
# Brewed Coffee                                          0.30                0%
# Brewed Coffee                                          0.50                0%
# Brewed Coffee                                          1.00                0%
# Brewed Coffee                                          1.00                0%
# Caffè Latte                                            6.00               10%
# ...                                                     ...               ...
# Strawberries & Crème (Without Whipped Cream)           5.00                6%
# Vanilla Bean (Without Whipped Cream)                   4.00                6%
# Vanilla Bean (Without Whipped Cream)                   3.00                6%
# Vanilla Bean (Without Whipped Cream)                   3.00                4%
# Vanilla Bean (Without Whipped Cream)                   5.00                8%
#
#                                              Vitamin C (% DV)  \
# Beverage
# Brewed Coffee                                              0%
# Brewed Coffee                                              0%
# Brewed Coffee                                              0%
# Brewed Coffee                                              0%
# Caffè Latte                                                0%
# ...                                                       ...
# Strawberries & Crème (Without Whipped Cream)               8%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
#
#                                               Calcium (% DV)  Iron (% DV)   \
# Beverage
# Brewed Coffee                                              0%           0%
# Brewed Coffee                                              0%           0%
# Brewed Coffee                                              0%           0%
# Brewed Coffee                                              2%           0%
# Caffè Latte                                               20%           0%
# ...                                                       ...          ...
# Strawberries & Crème (Without Whipped Cream)              20%          10%
# Vanilla Bean (Without Whipped Cream)                      10%           0%
# Vanilla Bean (Without Whipped Cream)                      10%           0%
# Vanilla Bean (Without Whipped Cream)                      10%           6%
# Vanilla Bean (Without Whipped Cream)                      15%           0%
#
#                                              Caffeine (mg)
# Beverage
# Brewed Coffee                                          175
# Brewed Coffee                                          260
# Brewed Coffee                                          330
# Brewed Coffee                                          410
# Caffè Latte                                             75
# ...                                                    ...
# Strawberries & Crème (Without Whipped Cream)             0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0
#
# [242 rows x 17 columns]

# %%
# displaying data in a formatted quick overview of the DataFrame structure
# will only work in jupyter notebook, othewise need to use: print(variable name)
mcd
# Out:
#                                                              Category  \
# Item
# Egg McMuffin                                                Breakfast
# Egg White Delight                                           Breakfast
# Sausage McMuffin                                            Breakfast
# Sausage McMuffin with Egg                                   Breakfast
# Sausage McMuffin with Egg Whites                            Breakfast
# ...                                                               ...
# McFlurry with Oreo Cookies (Small)                 Smoothies & Shakes
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
#
#                                                       Serving Size  Calories  \
# Item
# Egg McMuffin                                        4.8 oz (136 g)       300
# Egg White Delight                                   4.8 oz (135 g)       250
# Sausage McMuffin                                    3.9 oz (111 g)       370
# Sausage McMuffin with Egg                           5.7 oz (161 g)       450
# Sausage McMuffin with Egg Whites                    5.7 oz (161 g)       400
# ...                                                            ...       ...
# McFlurry with Oreo Cookies (Small)                 10.1 oz (285 g)       510
# McFlurry with Oreo Cookies (Medium)                13.4 oz (381 g)       690
# McFlurry with Oreo Cookies (Snack)                  6.7 oz (190 g)       340
# McFlurry with Reese's Peanut Butter Cups (Medium)  14.2 oz (403 g)       810
# McFlurry with Reese's Peanut Butter Cups (Snack)    7.1 oz (202 g)       410
#
#                                                    Calories from Fat  \
# Item
# Egg McMuffin                                                     120
# Egg White Delight                                                 70
# Sausage McMuffin                                                 200
# Sausage McMuffin with Egg                                        250
# Sausage McMuffin with Egg Whites                                 210
# ...                                                              ...
# McFlurry with Oreo Cookies (Small)                               150
# McFlurry with Oreo Cookies (Medium)                              200
# McFlurry with Oreo Cookies (Snack)                               100
# McFlurry with Reese's Peanut Butter Cups (Medium)                290
# McFlurry with Reese's Peanut Butter Cups (Snack)                 150
#
#                                                    Total Fat  \
# Item
# Egg McMuffin                                           13.00
# Egg White Delight                                       8.00
# Sausage McMuffin                                       23.00
# Sausage McMuffin with Egg                              28.00
# Sausage McMuffin with Egg Whites                       23.00
# ...                                                      ...
# McFlurry with Oreo Cookies (Small)                     17.00
# McFlurry with Oreo Cookies (Medium)                    23.00
# McFlurry with Oreo Cookies (Snack)                     11.00
# McFlurry with Reese's Peanut Butter Cups (Medium)      32.00
# McFlurry with Reese's Peanut Butter Cups (Snack)       16.00
#
#                                                    Total Fat (% Daily Value)  \
# Item
# Egg McMuffin                                                              20
# Egg White Delight                                                         12
# Sausage McMuffin                                                          35
# Sausage McMuffin with Egg                                                 43
# Sausage McMuffin with Egg Whites                                          35
# ...                                                                      ...
# McFlurry with Oreo Cookies (Small)                                        26
# McFlurry with Oreo Cookies (Medium)                                       35
# McFlurry with Oreo Cookies (Snack)                                        17
# McFlurry with Reese's Peanut Butter Cups (Medium)                         50
# McFlurry with Reese's Peanut Butter Cups (Snack)                          25
#
#                                                    Saturated Fat  \
# Item
# Egg McMuffin                                                5.00
# Egg White Delight                                           3.00
# Sausage McMuffin                                            8.00
# Sausage McMuffin with Egg                                  10.00
# Sausage McMuffin with Egg Whites                            8.00
# ...                                                          ...
# McFlurry with Oreo Cookies (Small)                          9.00
# McFlurry with Oreo Cookies (Medium)                        12.00
# McFlurry with Oreo Cookies (Snack)                          6.00
# McFlurry with Reese's Peanut Butter Cups (Medium)          15.00
# McFlurry with Reese's Peanut Butter Cups (Snack)            8.00
#
#                                                    Saturated Fat (% Daily Value)  \
# Item
# Egg McMuffin                                                                  25
# Egg White Delight                                                             15
# Sausage McMuffin                                                              42
# Sausage McMuffin with Egg                                                     52
# Sausage McMuffin with Egg Whites                                              42
# ...                                                                          ...
# McFlurry with Oreo Cookies (Small)                                            44
# McFlurry with Oreo Cookies (Medium)                                           58
# McFlurry with Oreo Cookies (Snack)                                            29
# McFlurry with Reese's Peanut Butter Cups (Medium)                             76
# McFlurry with Reese's Peanut Butter Cups (Snack)                              38
#
#                                                    Trans Fat  Cholesterol  \
# Item
# Egg McMuffin                                            0.00          260
# Egg White Delight                                       0.00           25
# Sausage McMuffin                                        0.00           45
# Sausage McMuffin with Egg                               0.00          285
# Sausage McMuffin with Egg Whites                        0.00           50
# ...                                                      ...          ...
# McFlurry with Oreo Cookies (Small)                      0.50           45
# McFlurry with Oreo Cookies (Medium)                     1.00           55
# McFlurry with Oreo Cookies (Snack)                      0.00           30
# McFlurry with Reese's Peanut Butter Cups (Medium)       1.00           60
# McFlurry with Reese's Peanut Butter Cups (Snack)        0.00           30
#
#                                                    ...  Carbohydrates  \
# Item                                               ...
# Egg McMuffin                                       ...             31
# Egg White Delight                                  ...             30
# Sausage McMuffin                                   ...             29
# Sausage McMuffin with Egg                          ...             30
# Sausage McMuffin with Egg Whites                   ...             30
# ...                                                ...            ...
# McFlurry with Oreo Cookies (Small)                 ...             80
# McFlurry with Oreo Cookies (Medium)                ...            106
# McFlurry with Oreo Cookies (Snack)                 ...             53
# McFlurry with Reese's Peanut Butter Cups (Medium)  ...            114
# McFlurry with Reese's Peanut Butter Cups (Snack)   ...             57
#
#                                                    Carbohydrates (% Daily Value)  \
# Item
# Egg McMuffin                                                                  10
# Egg White Delight                                                             10
# Sausage McMuffin                                                              10
# Sausage McMuffin with Egg                                                     10
# Sausage McMuffin with Egg Whites                                              10
# ...                                                                          ...
# McFlurry with Oreo Cookies (Small)                                            27
# McFlurry with Oreo Cookies (Medium)                                           35
# McFlurry with Oreo Cookies (Snack)                                            18
# McFlurry with Reese's Peanut Butter Cups (Medium)                             38
# McFlurry with Reese's Peanut Butter Cups (Snack)                              19
#
#                                                    Dietary Fiber  \
# Item
# Egg McMuffin                                                   4
# Egg White Delight                                              4
# Sausage McMuffin                                               4
# Sausage McMuffin with Egg                                      4
# Sausage McMuffin with Egg Whites                               4
# ...                                                          ...
# McFlurry with Oreo Cookies (Small)                             1
# McFlurry with Oreo Cookies (Medium)                            1
# McFlurry with Oreo Cookies (Snack)                             1
# McFlurry with Reese's Peanut Butter Cups (Medium)              2
# McFlurry with Reese's Peanut Butter Cups (Snack)               1
#
#                                                    Dietary Fiber (% Daily Value)  \
# Item
# Egg McMuffin                                                                  17
# Egg White Delight                                                             17
# Sausage McMuffin                                                              17
# Sausage McMuffin with Egg                                                     17
# Sausage McMuffin with Egg Whites                                              17
# ...                                                                          ...
# McFlurry with Oreo Cookies (Small)                                             4
# McFlurry with Oreo Cookies (Medium)                                            5
# McFlurry with Oreo Cookies (Snack)                                             2
# McFlurry with Reese's Peanut Butter Cups (Medium)                              9
# McFlurry with Reese's Peanut Butter Cups (Snack)                               5
#
#                                                    Sugars  Protein  \
# Item
# Egg McMuffin                                            3       17
# Egg White Delight                                       3       18
# Sausage McMuffin                                        2       14
# Sausage McMuffin with Egg                               2       21
# Sausage McMuffin with Egg Whites                        2       21
# ...                                                   ...      ...
# McFlurry with Oreo Cookies (Small)                     64       12
# McFlurry with Oreo Cookies (Medium)                    85       15
# McFlurry with Oreo Cookies (Snack)                     43        8
# McFlurry with Reese's Peanut Butter Cups (Medium)     103       21
# McFlurry with Reese's Peanut Butter Cups (Snack)       51       10
#
#                                                    Vitamin A (% Daily Value)  \
# Item
# Egg McMuffin                                                              10
# Egg White Delight                                                          6
# Sausage McMuffin                                                           8
# Sausage McMuffin with Egg                                                 15
# Sausage McMuffin with Egg Whites                                           6
# ...                                                                      ...
# McFlurry with Oreo Cookies (Small)                                        15
# McFlurry with Oreo Cookies (Medium)                                       20
# McFlurry with Oreo Cookies (Snack)                                        10
# McFlurry with Reese's Peanut Butter Cups (Medium)                         20
# McFlurry with Reese's Peanut Butter Cups (Snack)                          10
#
#                                                    Vitamin C (% Daily Value)  \
# Item
# Egg McMuffin                                                               0
# Egg White Delight                                                          0
# Sausage McMuffin                                                           0
# Sausage McMuffin with Egg                                                  0
# Sausage McMuffin with Egg Whites                                           0
# ...                                                                      ...
# McFlurry with Oreo Cookies (Small)                                         0
# McFlurry with Oreo Cookies (Medium)                                        0
# McFlurry with Oreo Cookies (Snack)                                         0
# McFlurry with Reese's Peanut Butter Cups (Medium)                          0
# McFlurry with Reese's Peanut Butter Cups (Snack)                           0
#
#                                                    Calcium (% Daily Value)  \
# Item
# Egg McMuffin                                                            25
# Egg White Delight                                                       25
# Sausage McMuffin                                                        25
# Sausage McMuffin with Egg                                               30
# Sausage McMuffin with Egg Whites                                        25
# ...                                                                    ...
# McFlurry with Oreo Cookies (Small)                                      40
# McFlurry with Oreo Cookies (Medium)                                     50
# McFlurry with Oreo Cookies (Snack)                                      25
# McFlurry with Reese's Peanut Butter Cups (Medium)                       60
# McFlurry with Reese's Peanut Butter Cups (Snack)                        30
#
#                                                    Iron (% Daily Value)
# Item
# Egg McMuffin                                                         15
# Egg White Delight                                                     8
# Sausage McMuffin                                                     10
# Sausage McMuffin with Egg                                            15
# Sausage McMuffin with Egg Whites                                     10
# ...                                                                 ...
# McFlurry with Oreo Cookies (Small)                                    8
# McFlurry with Oreo Cookies (Medium)                                  10
# McFlurry with Oreo Cookies (Snack)                                    6
# McFlurry with Reese's Peanut Butter Cups (Medium)                     6
# McFlurry with Reese's Peanut Butter Cups (Snack)                      4
#
# [260 rows x 23 columns]

# %% [markdown]
# #### Tail

# %% [markdown]
# Displaying tails (end) of dataframe.
#
# Using parenthesis allows for setting how many rows will be displayed.

# %%
# displaying the last 20 rows of the dataframe
sbux.tail(20)
# Out:
#                                                               Beverage_category  \
# Beverage
# Mocha                                         Frappuccino® Light Blended Coffee
# Caramel                                       Frappuccino® Light Blended Coffee
# Caramel                                       Frappuccino® Light Blended Coffee
# Caramel                                       Frappuccino® Light Blended Coffee
# Java Chip                                     Frappuccino® Light Blended Coffee
# Java Chip                                     Frappuccino® Light Blended Coffee
# Java Chip                                     Frappuccino® Light Blended Coffee
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Strawberries & Crème (Without Whipped Cream)         Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)                 Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)                 Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)                 Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)                 Frappuccino® Blended Crème
#
#                                                    Beverage_prep  Calories  \
# Beverage
# Mocha                                          Venti Nonfat Milk       210
# Caramel                                         Tall Nonfat Milk       100
# Caramel                                       Grande Nonfat Milk       150
# Caramel                                        Venti Nonfat Milk       200
# Java Chip                                       Tall Nonfat Milk       150
# Java Chip                                     Grande Nonfat Milk       220
# Java Chip                                      Venti Nonfat Milk       290
# Strawberries & Crème (Without Whipped Cream)    Tall Nonfat Milk       170
# Strawberries & Crème (Without Whipped Cream)          Whole Milk       190
# Strawberries & Crème (Without Whipped Cream)             Soymilk       170
# Strawberries & Crème (Without Whipped Cream)  Grande Nonfat Milk       230
# Strawberries & Crème (Without Whipped Cream)          Whole Milk       260
# Strawberries & Crème (Without Whipped Cream)             Soymilk       240
# Strawberries & Crème (Without Whipped Cream)   Venti Nonfat Milk       310
# Strawberries & Crème (Without Whipped Cream)          Whole Milk       350
# Strawberries & Crème (Without Whipped Cream)             Soymilk       320
# Vanilla Bean (Without Whipped Cream)            Tall Nonfat Milk       170
# Vanilla Bean (Without Whipped Cream)                  Whole Milk       200
# Vanilla Bean (Without Whipped Cream)                     Soymilk       180
# Vanilla Bean (Without Whipped Cream)          Grande Nonfat Milk       240
#
#                                               Total Fat (g)  Trans Fat (g)   \
# Beverage
# Mocha                                                     1            0.50
# Caramel                                                 0.1            0.00
# Caramel                                                 0.1            0.10
# Caramel                                                 0.1            0.10
# Java Chip                                                 3            2.00
# Java Chip                                                 4            3.00
# Java Chip                                                 5            4.00
# Strawberries & Crème (Without Whipped Cream)            0.1            0.10
# Strawberries & Crème (Without Whipped Cream)              3            1.50
# Strawberries & Crème (Without Whipped Cream)            1.5            0.20
# Strawberries & Crème (Without Whipped Cream)            0.2            0.10
# Strawberries & Crème (Without Whipped Cream)              4            2.00
# Strawberries & Crème (Without Whipped Cream)              2            0.20
# Strawberries & Crème (Without Whipped Cream)            0.2            0.10
# Strawberries & Crème (Without Whipped Cream)              6            3.00
# Strawberries & Crème (Without Whipped Cream)            3 2            0.40
# Vanilla Bean (Without Whipped Cream)                    0.1            0.10
# Vanilla Bean (Without Whipped Cream)                    3.5            2.00
# Vanilla Bean (Without Whipped Cream)                    1.5            0.20
# Vanilla Bean (Without Whipped Cream)                    0.1            0.10
#
#                                               Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Mocha                                                      0.00             5
# Caramel                                                    0.00             0
# Caramel                                                    0.00             0
# Caramel                                                    0.00             5
# Java Chip                                                  0.00             0
# Java Chip                                                  0.00             0
# Java Chip                                                  0.00             5
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Strawberries & Crème (Without Whipped Cream)               0.10            10
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Strawberries & Crème (Without Whipped Cream)               0.10            10
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Strawberries & Crème (Without Whipped Cream)               0.00             5
# Strawberries & Crème (Without Whipped Cream)               0.20            15
# Strawberries & Crème (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.10            10
# Vanilla Bean (Without Whipped Cream)                       0.00             0
# Vanilla Bean (Without Whipped Cream)                       0.00             5
#
#                                                Total Carbohydrates (g)   \
# Beverage
# Mocha                                                               280
# Caramel                                                             140
# Caramel                                                             200
# Caramel                                                             270
# Java Chip                                                           170
# Java Chip                                                           240
# Java Chip                                                           320
# Strawberries & Crème (Without Whipped Cream)                        140
# Strawberries & Crème (Without Whipped Cream)                        140
# Strawberries & Crème (Without Whipped Cream)                        135
# Strawberries & Crème (Without Whipped Cream)                        190
# Strawberries & Crème (Without Whipped Cream)                        190
# Strawberries & Crème (Without Whipped Cream)                        180
# Strawberries & Crème (Without Whipped Cream)                        260
# Strawberries & Crème (Without Whipped Cream)                        260
# Strawberries & Crème (Without Whipped Cream)                        250
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                160
# Vanilla Bean (Without Whipped Cream)                                230
#
#                                               Cholesterol (mg)  \
# Beverage
# Mocha                                                       46
# Caramel                                                     23
# Caramel                                                     33
# Caramel                                                     44
# Java Chip                                                   30
# Java Chip                                                   43
# Java Chip                                                   58
# Strawberries & Crème (Without Whipped Cream)                39
# Strawberries & Crème (Without Whipped Cream)                38
# Strawberries & Crème (Without Whipped Cream)                37
# Strawberries & Crème (Without Whipped Cream)                53
# Strawberries & Crème (Without Whipped Cream)                53
# Strawberries & Crème (Without Whipped Cream)                51
# Strawberries & Crème (Without Whipped Cream)                70
# Strawberries & Crème (Without Whipped Cream)                70
# Strawberries & Crème (Without Whipped Cream)                67
# Vanilla Bean (Without Whipped Cream)                        39
# Vanilla Bean (Without Whipped Cream)                        39
# Vanilla Bean (Without Whipped Cream)                        37
# Vanilla Bean (Without Whipped Cream)                        56
#
#                                                Dietary Fibre (g)   Sugars (g)  \
# Beverage
# Mocha                                                          1           42
# Caramel                                                        0           23
# Caramel                                                        0           32
# Caramel                                                        0           43
# Java Chip                                                      1           27
# Java Chip                                                      2           39
# Java Chip                                                      2           52
# Strawberries & Crème (Without Whipped Cream)                   0           38
# Strawberries & Crème (Without Whipped Cream)                   0           37
# Strawberries & Crème (Without Whipped Cream)                   1           35
# Strawberries & Crème (Without Whipped Cream)                   0           52
# Strawberries & Crème (Without Whipped Cream)                   0           52
# Strawberries & Crème (Without Whipped Cream)                   1           49
# Strawberries & Crème (Without Whipped Cream)                   0           69
# Strawberries & Crème (Without Whipped Cream)                   0           68
# Strawberries & Crème (Without Whipped Cream)                   1           64
# Vanilla Bean (Without Whipped Cream)                           0           38
# Vanilla Bean (Without Whipped Cream)                           0           38
# Vanilla Bean (Without Whipped Cream)                           1           35
# Vanilla Bean (Without Whipped Cream)                           0           55
#
#                                                Protein (g)  Vitamin A (% DV)   \
# Beverage
# Mocha                                                  6.00                8%
# Caramel                                                3.00                4%
# Caramel                                                3.00                6%
# Caramel                                                5.00                8%
# Java Chip                                              4.00                4%
# Java Chip                                              5.00                6%
# Java Chip                                              7.00                8%
# Strawberries & Crème (Without Whipped Cream)           3.00                6%
# Strawberries & Crème (Without Whipped Cream)           3.00                4%
# Strawberries & Crème (Without Whipped Cream)           3.00                4%
# Strawberries & Crème (Without Whipped Cream)           4.00                8%
# Strawberries & Crème (Without Whipped Cream)           4.00                6%
# Strawberries & Crème (Without Whipped Cream)           3.00                4%
# Strawberries & Crème (Without Whipped Cream)           6.00               10%
# Strawberries & Crème (Without Whipped Cream)           6.00                8%
# Strawberries & Crème (Without Whipped Cream)           5.00                6%
# Vanilla Bean (Without Whipped Cream)                   4.00                6%
# Vanilla Bean (Without Whipped Cream)                   3.00                6%
# Vanilla Bean (Without Whipped Cream)                   3.00                4%
# Vanilla Bean (Without Whipped Cream)                   5.00                8%
#
#                                              Vitamin C (% DV)  \
# Beverage
# Mocha                                                      0%
# Caramel                                                    0%
# Caramel                                                    0%
# Caramel                                                    0%
# Java Chip                                                  0%
# Java Chip                                                  0%
# Java Chip                                                  0%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               6%
# Strawberries & Crème (Without Whipped Cream)               8%
# Strawberries & Crème (Without Whipped Cream)               8%
# Strawberries & Crème (Without Whipped Cream)               8%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
# Vanilla Bean (Without Whipped Cream)                       0%
#
#                                               Calcium (% DV)  Iron (% DV)   \
# Beverage
# Mocha                                                     15%          10%
# Caramel                                                    8%           0%
# Caramel                                                   10%           0%
# Caramel                                                   15%           2%
# Java Chip                                                 10%          20%
# Java Chip                                                 10%          25%
# Java Chip                                                 15%          35%
# Strawberries & Crème (Without Whipped Cream)              10%           2%
# Strawberries & Crème (Without Whipped Cream)              10%           2%
# Strawberries & Crème (Without Whipped Cream)              10%           6%
# Strawberries & Crème (Without Whipped Cream)              15%           4%
# Strawberries & Crème (Without Whipped Cream)              15%           4%
# Strawberries & Crème (Without Whipped Cream)              15%           8%
# Strawberries & Crème (Without Whipped Cream)              20%           4%
# Strawberries & Crème (Without Whipped Cream)              20%           4%
# Strawberries & Crème (Without Whipped Cream)              20%          10%
# Vanilla Bean (Without Whipped Cream)                      10%           0%
# Vanilla Bean (Without Whipped Cream)                      10%           0%
# Vanilla Bean (Without Whipped Cream)                      10%           6%
# Vanilla Bean (Without Whipped Cream)                      15%           0%
#
#                                              Caffeine (mg)
# Beverage
# Mocha                                                  130
# Caramel                                                 65
# Caramel                                                 90
# Caramel                                                120
# Java Chip                                               70
# Java Chip                                              105
# Java Chip                                              165
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Strawberries & Crème (Without Whipped Cream)             0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0
# Vanilla Bean (Without Whipped Cream)                     0

# %%
# displaying the last 20 rows of the dataframe
mcd.tail(20)
# Out:
#                                                              Category  \
# Item
# Mango Pineapple Smoothie (Large)                   Smoothies & Shakes
# Vanilla Shake (Small)                              Smoothies & Shakes
# Vanilla Shake (Medium)                             Smoothies & Shakes
# Vanilla Shake (Large)                              Smoothies & Shakes
# Strawberry Shake (Small)                           Smoothies & Shakes
# Strawberry Shake (Medium)                          Smoothies & Shakes
# Strawberry Shake (Large)                           Smoothies & Shakes
# Chocolate Shake (Small)                            Smoothies & Shakes
# Chocolate Shake (Medium)                           Smoothies & Shakes
# Chocolate Shake (Large)                            Smoothies & Shakes
# Shamrock Shake (Medium)                            Smoothies & Shakes
# Shamrock Shake (Large)                             Smoothies & Shakes
# McFlurry with M&M’s Candies (Small)                Smoothies & Shakes
# McFlurry with M&M’s Candies (Medium)               Smoothies & Shakes
# McFlurry with M&M’s Candies (Snack)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Small)                 Smoothies & Shakes
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
#
#                                                       Serving Size  Calories  \
# Item
# Mango Pineapple Smoothie (Large)                      22 fl oz cup       340
# Vanilla Shake (Small)                                 12 fl oz cup       530
# Vanilla Shake (Medium)                                16 fl oz cup       660
# Vanilla Shake (Large)                                 22 fl oz cup       820
# Strawberry Shake (Small)                              12 fl oz cup       550
# Strawberry Shake (Medium)                             16 fl oz cup       690
# Strawberry Shake (Large)                              22 fl oz cup       850
# Chocolate Shake (Small)                               12 fl oz cup       560
# Chocolate Shake (Medium)                              16 fl oz cup       700
# Chocolate Shake (Large)                               22 fl oz cup       850
# Shamrock Shake (Medium)                               16 fl oz cup       660
# Shamrock Shake (Large)                                22 fl oz cup       820
# McFlurry with M&M’s Candies (Small)                10.9 oz (310 g)       650
# McFlurry with M&M’s Candies (Medium)               16.2 oz (460 g)       930
# McFlurry with M&M’s Candies (Snack)                 7.3 oz (207 g)       430
# McFlurry with Oreo Cookies (Small)                 10.1 oz (285 g)       510
# McFlurry with Oreo Cookies (Medium)                13.4 oz (381 g)       690
# McFlurry with Oreo Cookies (Snack)                  6.7 oz (190 g)       340
# McFlurry with Reese's Peanut Butter Cups (Medium)  14.2 oz (403 g)       810
# McFlurry with Reese's Peanut Butter Cups (Snack)    7.1 oz (202 g)       410
#
#                                                    Calories from Fat  \
# Item
# Mango Pineapple Smoothie (Large)                                  10
# Vanilla Shake (Small)                                            140
# Vanilla Shake (Medium)                                           170
# Vanilla Shake (Large)                                            210
# Strawberry Shake (Small)                                         150
# Strawberry Shake (Medium)                                        180
# Strawberry Shake (Large)                                         210
# Chocolate Shake (Small)                                          150
# Chocolate Shake (Medium)                                         180
# Chocolate Shake (Large)                                          210
# Shamrock Shake (Medium)                                          170
# Shamrock Shake (Large)                                           210
# McFlurry with M&M’s Candies (Small)                              210
# McFlurry with M&M’s Candies (Medium)                             290
# McFlurry with M&M’s Candies (Snack)                              140
# McFlurry with Oreo Cookies (Small)                               150
# McFlurry with Oreo Cookies (Medium)                              200
# McFlurry with Oreo Cookies (Snack)                               100
# McFlurry with Reese's Peanut Butter Cups (Medium)                290
# McFlurry with Reese's Peanut Butter Cups (Snack)                 150
#
#                                                    Total Fat  \
# Item
# Mango Pineapple Smoothie (Large)                        1.00
# Vanilla Shake (Small)                                  15.00
# Vanilla Shake (Medium)                                 19.00
# Vanilla Shake (Large)                                  23.00
# Strawberry Shake (Small)                               16.00
# Strawberry Shake (Medium)                              20.00
# Strawberry Shake (Large)                               24.00
# Chocolate Shake (Small)                                16.00
# Chocolate Shake (Medium)                               20.00
# Chocolate Shake (Large)                                23.00
# Shamrock Shake (Medium)                                19.00
# Shamrock Shake (Large)                                 23.00
# McFlurry with M&M’s Candies (Small)                    23.00
# McFlurry with M&M’s Candies (Medium)                   33.00
# McFlurry with M&M’s Candies (Snack)                    15.00
# McFlurry with Oreo Cookies (Small)                     17.00
# McFlurry with Oreo Cookies (Medium)                    23.00
# McFlurry with Oreo Cookies (Snack)                     11.00
# McFlurry with Reese's Peanut Butter Cups (Medium)      32.00
# McFlurry with Reese's Peanut Butter Cups (Snack)       16.00
#
#                                                    Total Fat (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                           2
# Vanilla Shake (Small)                                                     24
# Vanilla Shake (Medium)                                                    29
# Vanilla Shake (Large)                                                     35
# Strawberry Shake (Small)                                                  25
# Strawberry Shake (Medium)                                                 30
# Strawberry Shake (Large)                                                  36
# Chocolate Shake (Small)                                                   25
# Chocolate Shake (Medium)                                                  30
# Chocolate Shake (Large)                                                   36
# Shamrock Shake (Medium)                                                   29
# Shamrock Shake (Large)                                                    35
# McFlurry with M&M’s Candies (Small)                                       35
# McFlurry with M&M’s Candies (Medium)                                      50
# McFlurry with M&M’s Candies (Snack)                                       24
# McFlurry with Oreo Cookies (Small)                                        26
# McFlurry with Oreo Cookies (Medium)                                       35
# McFlurry with Oreo Cookies (Snack)                                        17
# McFlurry with Reese's Peanut Butter Cups (Medium)                         50
# McFlurry with Reese's Peanut Butter Cups (Snack)                          25
#
#                                                    Saturated Fat  \
# Item
# Mango Pineapple Smoothie (Large)                            0.50
# Vanilla Shake (Small)                                      10.00
# Vanilla Shake (Medium)                                     12.00
# Vanilla Shake (Large)                                      15.00
# Strawberry Shake (Small)                                   10.00
# Strawberry Shake (Medium)                                  13.00
# Strawberry Shake (Large)                                   15.00
# Chocolate Shake (Small)                                    10.00
# Chocolate Shake (Medium)                                   12.00
# Chocolate Shake (Large)                                    15.00
# Shamrock Shake (Medium)                                    12.00
# Shamrock Shake (Large)                                     15.00
# McFlurry with M&M’s Candies (Small)                        14.00
# McFlurry with M&M’s Candies (Medium)                       20.00
# McFlurry with M&M’s Candies (Snack)                        10.00
# McFlurry with Oreo Cookies (Small)                          9.00
# McFlurry with Oreo Cookies (Medium)                        12.00
# McFlurry with Oreo Cookies (Snack)                          6.00
# McFlurry with Reese's Peanut Butter Cups (Medium)          15.00
# McFlurry with Reese's Peanut Butter Cups (Snack)            8.00
#
#                                                    Saturated Fat (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                               3
# Vanilla Shake (Small)                                                         49
# Vanilla Shake (Medium)                                                        61
# Vanilla Shake (Large)                                                         73
# Strawberry Shake (Small)                                                      52
# Strawberry Shake (Medium)                                                     63
# Strawberry Shake (Large)                                                      75
# Chocolate Shake (Small)                                                       51
# Chocolate Shake (Medium)                                                      62
# Chocolate Shake (Large)                                                       74
# Shamrock Shake (Medium)                                                       61
# Shamrock Shake (Large)                                                        73
# McFlurry with M&M’s Candies (Small)                                           72
# McFlurry with M&M’s Candies (Medium)                                         102
# McFlurry with M&M’s Candies (Snack)                                           48
# McFlurry with Oreo Cookies (Small)                                            44
# McFlurry with Oreo Cookies (Medium)                                           58
# McFlurry with Oreo Cookies (Snack)                                            29
# McFlurry with Reese's Peanut Butter Cups (Medium)                             76
# McFlurry with Reese's Peanut Butter Cups (Snack)                              38
#
#                                                    Trans Fat  Cholesterol  \
# Item
# Mango Pineapple Smoothie (Large)                        0.00            5
# Vanilla Shake (Small)                                   1.00           60
# Vanilla Shake (Medium)                                  1.00           75
# Vanilla Shake (Large)                                   1.00           90
# Strawberry Shake (Small)                                1.00           60
# Strawberry Shake (Medium)                               1.00           75
# Strawberry Shake (Large)                                1.00           90
# Chocolate Shake (Small)                                 1.00           60
# Chocolate Shake (Medium)                                1.00           75
# Chocolate Shake (Large)                                 1.00           85
# Shamrock Shake (Medium)                                 1.00           75
# Shamrock Shake (Large)                                  1.00           90
# McFlurry with M&M’s Candies (Small)                     0.50           50
# McFlurry with M&M’s Candies (Medium)                    1.00           75
# McFlurry with M&M’s Candies (Snack)                     0.00           35
# McFlurry with Oreo Cookies (Small)                      0.50           45
# McFlurry with Oreo Cookies (Medium)                     1.00           55
# McFlurry with Oreo Cookies (Snack)                      0.00           30
# McFlurry with Reese's Peanut Butter Cups (Medium)       1.00           60
# McFlurry with Reese's Peanut Butter Cups (Snack)        0.00           30
#
#                                                    ...  Carbohydrates  \
# Item                                               ...
# Mango Pineapple Smoothie (Large)                   ...             78
# Vanilla Shake (Small)                              ...             86
# Vanilla Shake (Medium)                             ...            109
# Vanilla Shake (Large)                              ...            135
# Strawberry Shake (Small)                           ...             90
# Strawberry Shake (Medium)                          ...            114
# Strawberry Shake (Large)                           ...            140
# Chocolate Shake (Small)                            ...             91
# Chocolate Shake (Medium)                           ...            114
# Chocolate Shake (Large)                            ...            141
# Shamrock Shake (Medium)                            ...            109
# Shamrock Shake (Large)                             ...            135
# McFlurry with M&M’s Candies (Small)                ...             96
# McFlurry with M&M’s Candies (Medium)               ...            139
# McFlurry with M&M’s Candies (Snack)                ...             64
# McFlurry with Oreo Cookies (Small)                 ...             80
# McFlurry with Oreo Cookies (Medium)                ...            106
# McFlurry with Oreo Cookies (Snack)                 ...             53
# McFlurry with Reese's Peanut Butter Cups (Medium)  ...            114
# McFlurry with Reese's Peanut Butter Cups (Snack)   ...             57
#
#                                                    Carbohydrates (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                              26
# Vanilla Shake (Small)                                                         29
# Vanilla Shake (Medium)                                                        36
# Vanilla Shake (Large)                                                         45
# Strawberry Shake (Small)                                                      30
# Strawberry Shake (Medium)                                                     38
# Strawberry Shake (Large)                                                      47
# Chocolate Shake (Small)                                                       30
# Chocolate Shake (Medium)                                                      38
# Chocolate Shake (Large)                                                       47
# Shamrock Shake (Medium)                                                       36
# Shamrock Shake (Large)                                                        45
# McFlurry with M&M’s Candies (Small)                                           32
# McFlurry with M&M’s Candies (Medium)                                          46
# McFlurry with M&M’s Candies (Snack)                                           21
# McFlurry with Oreo Cookies (Small)                                            27
# McFlurry with Oreo Cookies (Medium)                                           35
# McFlurry with Oreo Cookies (Snack)                                            18
# McFlurry with Reese's Peanut Butter Cups (Medium)                             38
# McFlurry with Reese's Peanut Butter Cups (Snack)                              19
#
#                                                    Dietary Fiber  \
# Item
# Mango Pineapple Smoothie (Large)                               2
# Vanilla Shake (Small)                                          0
# Vanilla Shake (Medium)                                         0
# Vanilla Shake (Large)                                          0
# Strawberry Shake (Small)                                       0
# Strawberry Shake (Medium)                                      0
# Strawberry Shake (Large)                                       0
# Chocolate Shake (Small)                                        1
# Chocolate Shake (Medium)                                       2
# Chocolate Shake (Large)                                        2
# Shamrock Shake (Medium)                                        0
# Shamrock Shake (Large)                                         0
# McFlurry with M&M’s Candies (Small)                            1
# McFlurry with M&M’s Candies (Medium)                           2
# McFlurry with M&M’s Candies (Snack)                            1
# McFlurry with Oreo Cookies (Small)                             1
# McFlurry with Oreo Cookies (Medium)                            1
# McFlurry with Oreo Cookies (Snack)                             1
# McFlurry with Reese's Peanut Butter Cups (Medium)              2
# McFlurry with Reese's Peanut Butter Cups (Snack)               1
#
#                                                    Dietary Fiber (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                               6
# Vanilla Shake (Small)                                                          0
# Vanilla Shake (Medium)                                                         0
# Vanilla Shake (Large)                                                          0
# Strawberry Shake (Small)                                                       0
# Strawberry Shake (Medium)                                                      0
# Strawberry Shake (Large)                                                       0
# Chocolate Shake (Small)                                                        5
# Chocolate Shake (Medium)                                                       6
# Chocolate Shake (Large)                                                        8
# Shamrock Shake (Medium)                                                        0
# Shamrock Shake (Large)                                                         0
# McFlurry with M&M’s Candies (Small)                                            6
# McFlurry with M&M’s Candies (Medium)                                           7
# McFlurry with M&M’s Candies (Snack)                                            4
# McFlurry with Oreo Cookies (Small)                                             4
# McFlurry with Oreo Cookies (Medium)                                            5
# McFlurry with Oreo Cookies (Snack)                                             2
# McFlurry with Reese's Peanut Butter Cups (Medium)                              9
# McFlurry with Reese's Peanut Butter Cups (Snack)                               5
#
#                                                    Sugars  Protein  \
# Item
# Mango Pineapple Smoothie (Large)                       72        4
# Vanilla Shake (Small)                                  63       11
# Vanilla Shake (Medium)                                 81       14
# Vanilla Shake (Large)                                 101       18
# Strawberry Shake (Small)                               79       12
# Strawberry Shake (Medium)                             100       15
# Strawberry Shake (Large)                              123       18
# Chocolate Shake (Small)                                77       12
# Chocolate Shake (Medium)                               97       15
# Chocolate Shake (Large)                               120       19
# Shamrock Shake (Medium)                                93       14
# Shamrock Shake (Large)                                115       18
# McFlurry with M&M’s Candies (Small)                    89       13
# McFlurry with M&M’s Candies (Medium)                  128       20
# McFlurry with M&M’s Candies (Snack)                    59        9
# McFlurry with Oreo Cookies (Small)                     64       12
# McFlurry with Oreo Cookies (Medium)                    85       15
# McFlurry with Oreo Cookies (Snack)                     43        8
# McFlurry with Reese's Peanut Butter Cups (Medium)     103       21
# McFlurry with Reese's Peanut Butter Cups (Snack)       51       10
#
#                                                    Vitamin A (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                          50
# Vanilla Shake (Small)                                                     20
# Vanilla Shake (Medium)                                                    25
# Vanilla Shake (Large)                                                     30
# Strawberry Shake (Small)                                                  20
# Strawberry Shake (Medium)                                                 25
# Strawberry Shake (Large)                                                  30
# Chocolate Shake (Small)                                                   20
# Chocolate Shake (Medium)                                                  25
# Chocolate Shake (Large)                                                   30
# Shamrock Shake (Medium)                                                   25
# Shamrock Shake (Large)                                                    30
# McFlurry with M&M’s Candies (Small)                                       15
# McFlurry with M&M’s Candies (Medium)                                      25
# McFlurry with M&M’s Candies (Snack)                                       10
# McFlurry with Oreo Cookies (Small)                                        15
# McFlurry with Oreo Cookies (Medium)                                       20
# McFlurry with Oreo Cookies (Snack)                                        10
# McFlurry with Reese's Peanut Butter Cups (Medium)                         20
# McFlurry with Reese's Peanut Butter Cups (Snack)                          10
#
#                                                    Vitamin C (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                          30
# Vanilla Shake (Small)                                                      0
# Vanilla Shake (Medium)                                                     0
# Vanilla Shake (Large)                                                      0
# Strawberry Shake (Small)                                                   0
# Strawberry Shake (Medium)                                                  0
# Strawberry Shake (Large)                                                   0
# Chocolate Shake (Small)                                                    0
# Chocolate Shake (Medium)                                                   0
# Chocolate Shake (Large)                                                    0
# Shamrock Shake (Medium)                                                    0
# Shamrock Shake (Large)                                                     0
# McFlurry with M&M’s Candies (Small)                                        0
# McFlurry with M&M’s Candies (Medium)                                       0
# McFlurry with M&M’s Candies (Snack)                                        0
# McFlurry with Oreo Cookies (Small)                                         0
# McFlurry with Oreo Cookies (Medium)                                        0
# McFlurry with Oreo Cookies (Snack)                                         0
# McFlurry with Reese's Peanut Butter Cups (Medium)                          0
# McFlurry with Reese's Peanut Butter Cups (Snack)                           0
#
#                                                    Calcium (% Daily Value)  \
# Item
# Mango Pineapple Smoothie (Large)                                        10
# Vanilla Shake (Small)                                                   40
# Vanilla Shake (Medium)                                                  50
# Vanilla Shake (Large)                                                   60
# Strawberry Shake (Small)                                                40
# Strawberry Shake (Medium)                                               50
# Strawberry Shake (Large)                                                70
# Chocolate Shake (Small)                                                 40
# Chocolate Shake (Medium)                                                50
# Chocolate Shake (Large)                                                 60
# Shamrock Shake (Medium)                                                 50
# Shamrock Shake (Large)                                                  60
# McFlurry with M&M’s Candies (Small)                                     45
# McFlurry with M&M’s Candies (Medium)                                    70
# McFlurry with M&M’s Candies (Snack)                                     30
# McFlurry with Oreo Cookies (Small)                                      40
# McFlurry with Oreo Cookies (Medium)                                     50
# McFlurry with Oreo Cookies (Snack)                                      25
# McFlurry with Reese's Peanut Butter Cups (Medium)                       60
# McFlurry with Reese's Peanut Butter Cups (Snack)                        30
#
#                                                    Iron (% Daily Value)
# Item
# Mango Pineapple Smoothie (Large)                                      2
# Vanilla Shake (Small)                                                 0
# Vanilla Shake (Medium)                                                0
# Vanilla Shake (Large)                                                 0
# Strawberry Shake (Small)                                              0
# Strawberry Shake (Medium)                                             0
# Strawberry Shake (Large)                                              0
# Chocolate Shake (Small)                                               8
# Chocolate Shake (Medium)                                             10
# Chocolate Shake (Large)                                              15
# Shamrock Shake (Medium)                                               0
# Shamrock Shake (Large)                                                0
# McFlurry with M&M’s Candies (Small)                                   8
# McFlurry with M&M’s Candies (Medium)                                 10
# McFlurry with M&M’s Candies (Snack)                                   4
# McFlurry with Oreo Cookies (Small)                                    8
# McFlurry with Oreo Cookies (Medium)                                  10
# McFlurry with Oreo Cookies (Snack)                                    6
# McFlurry with Reese's Peanut Butter Cups (Medium)                     6
# McFlurry with Reese's Peanut Butter Cups (Snack)                      4
#
# [20 rows x 23 columns]

# %% [markdown]
# #### Reviewing Dataframe Columns
#
# **Column  names as a list**:

# %%
# displaying column names
sbux.columns
# displaying column names in list form
list(sbux.columns)
# Out:
# ['Beverage_category',
#  'Beverage_prep',
#  'Calories',
#  ' Total Fat (g)',
#  'Trans Fat (g) ',
#  'Saturated Fat (g)',
#  ' Sodium (mg)',
#  ' Total Carbohydrates (g) ',
#  'Cholesterol (mg)',
#  ' Dietary Fibre (g)',
#  ' Sugars (g)',
#  ' Protein (g) ',
#  'Vitamin A (% DV) ',
#  'Vitamin C (% DV)',
#  ' Calcium (% DV) ',
#  'Iron (% DV) ',
#  'Caffeine (mg)']

# %%
# displaying column names
mcd.columns
# displaying column names in list form
list(mcd.columns)
# Out:
# ['Category',
#  'Serving Size',
#  'Calories',
#  'Calories from Fat',
#  'Total Fat',
#  'Total Fat (% Daily Value)',
#  'Saturated Fat',
#  'Saturated Fat (% Daily Value)',
#  'Trans Fat',
#  'Cholesterol',
#  'Cholesterol (% Daily Value)',
#  'Sodium',
#  'Sodium (% Daily Value)',
#  'Carbohydrates',
#  'Carbohydrates (% Daily Value)',
#  'Dietary Fiber',
#  'Dietary Fiber (% Daily Value)',
#  'Sugars',
#  'Protein',
#  'Vitamin A (% Daily Value)',
#  'Vitamin C (% Daily Value)',
#  'Calcium (% Daily Value)',
#  'Iron (% Daily Value)']

# %% [markdown]
# **Column Similarities & Difference**:

# %% [markdown]
# Noting *similar* columns that will be interesting for comparison:
# - Calories
# - Fat: 1- Total Fat, 2- Trans Fat, 3- Saturated Fat
# - Carbs: 1- Total Carbhydreates/ Carbohydrates, 2- Sugars, 3- Dietary Fiber
# - Protein
# - Sodium
# - Cholesterol
# - Vitamin A
# - Vitamin C
# - Calcium
# - Iron
# - Beverage Category / Category

# %% [markdown]
# Noting *distinct* columns that will not allow for comparison:
# - Beverage prep (only on SBUX)
# - Caffeine (only on SBUX)
# - Serving size (only on MCD)
# - Calories from Fat (only on MCD)
# - % Daily Value of: Total Fat, Saturated Fat, Cholesterol, Sodium, Carbohydrates, Dietary Fiber (only on MCD)

# %% [markdown]
# **Analysis of distinct columns**

# %%
# analyzing value counts of specific columns 
sbux["Beverage_prep"].value_counts()
# Out:
# Beverage_prep
# Soymilk               66
# 2% Milk               50
# Grande Nonfat Milk    26
# Tall Nonfat Milk      23
# Venti Nonfat Milk     22
# Whole Milk            16
# Short Nonfat Milk     12
# Tall                   7
# Grande                 7
# Venti                  7
# Short                  4
# Solo                   1
# Doppio                 1
# Name: count, dtype: int64

# %%
# analyzing value counts of specific columns 
sbux["Caffeine (mg)"].value_counts()
# Out:
# Caffeine (mg)
# 75        37
# 0         35
# 150       34
# 70        14
# varies    12
# 95        11
# Varies    10
# 110        9
# 130        7
# 25         6
# 120        6
# 90         4
# 175        4
# 20         3
# 125        3
# 10         3
# 145        3
# 50         3
# 100        3
# 140        3
# 55         3
# 80         3
# 180        3
# 85         3
# 30         3
# 15         3
# 170        3
# 165        2
# 410        1
# 235        1
# 330        1
# 225        1
# 260        1
# 300        1
# 65         1
# 105        1
# Name: count, dtype: int64

# %%
# analyzing value counts of specific columns 
mcd["Serving Size"].value_counts()
# Out:
# Serving Size
# 16 fl oz cup       45
# 12 fl oz cup       38
# 22 fl oz cup       20
# 20 fl oz cup       16
# 30 fl oz cup        7
#                    ..
# 8 oz (227 g)        1
# 7.4 oz (211 g)      1
# 4 oz (114 g)        1
# 2 oz (56 g)         1
# 14.2 oz (403 g)     1
# Name: count, Length: 107, dtype: int64

# %%
# analyzing value counts of specific columns 
mcd["Calories from Fat"].value_counts()
# Out:
# Calories from Fat
# 0       54
# 80      16
# 150     11
# 120     10
# 200     10
# 210      9
# 180      8
# 280      8
# 100      7
# 40       7
# 170      7
# 70       7
# 30       6
# 60       6
# 240      6
# 90       6
# 140      6
# 250      5
# 10       5
# 5        5
# 190      5
# 35       4
# 45       4
# 220      4
# 290      4
# 230      4
# 50       4
# 110      4
# 130      3
# 160      3
# 270      2
# 20       2
# 330      2
# 300      2
# 1060     1
# 530      1
# 540      1
# 410      1
# 360      1
# 310      1
# 380      1
# 260      1
# 430      1
# 470      1
# 370      1
# 510      1
# 450      1
# 340      1
# Name: count, dtype: int64

# %% [markdown]
# **Column Findings**
#
# Upon initial analysis:
#
# Consider *merging*:
# - "Beverage Prep (SBUX)" column with the "Beverage" column
# -  "Serving Size (MCD)" column with the "Beverage" column
#
# Consider *deleting*:
# - Caffeine (SBUX)
# - Calories from Fat (MCD)
# - % Daily Value of: Total Fat, Saturated Fat, Cholesterol, Sodium, Carbohydrates, Dietary Fiber (MCD)

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# #### Missing Values
#
# **Assessing for missing values**:
#
# It is important to identify if there are any null values in the dataframes.

# %%
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for: # of non-null values per column, fit of asssigned data types
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 242 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          242 non-null    object
#  1   Beverage_prep              242 non-null    object
#  2   Calories                   242 non-null    int64
#  3    Total Fat (g)             242 non-null    object
#  4   Trans Fat (g)              242 non-null    float64
#  5   Saturated Fat (g)          242 non-null    float64
#  6    Sodium (mg)               242 non-null    int64
#  7    Total Carbohydrates (g)   242 non-null    int64
#  8   Cholesterol (mg)           242 non-null    int64
#  9    Dietary Fibre (g)         242 non-null    int64
#  10   Sugars (g)                242 non-null    int64
#  11   Protein (g)               242 non-null    float64
#  12  Vitamin A (% DV)           242 non-null    object
#  13  Vitamin C (% DV)           242 non-null    object
#  14   Calcium (% DV)            242 non-null    object
#  15  Iron (% DV)                242 non-null    object
#  16  Caffeine (mg)              241 non-null    object
# dtypes: float64(3), int64(6), object(8)
# memory usage: 34.0+ KB

# %%
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for: # of non-null values per column, fit of asssigned data types
mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Egg McMuffin to McFlurry with Reese's Peanut Butter Cups (Snack)
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Serving Size                   260 non-null    object
#  2   Calories                       260 non-null    int64
#  3   Calories from Fat              260 non-null    int64
#  4   Total Fat                      260 non-null    float64
#  5   Total Fat (% Daily Value)      260 non-null    int64
#  6   Saturated Fat                  260 non-null    float64
#  7   Saturated Fat (% Daily Value)  260 non-null    int64
#  8   Trans Fat                      260 non-null    float64
#  9   Cholesterol                    260 non-null    int64
#  10  Cholesterol (% Daily Value)    260 non-null    int64
#  11  Sodium                         260 non-null    int64
#  12  Sodium (% Daily Value)         260 non-null    int64
#  13  Carbohydrates                  260 non-null    int64
#  14  Carbohydrates (% Daily Value)  260 non-null    int64
#  15  Dietary Fiber                  260 non-null    int64
#  16  Dietary Fiber (% Daily Value)  260 non-null    int64
#  17  Sugars                         260 non-null    int64
#  18  Protein                        260 non-null    int64
#  19  Vitamin A (% Daily Value)      260 non-null    int64
#  20  Vitamin C (% Daily Value)      260 non-null    int64
#  21  Calcium (% Daily Value)        260 non-null    int64
#  22  Iron (% Daily Value)           260 non-null    int64
# dtypes: float64(3), int64(18), object(2)
# memory usage: 48.8+ KB

# %% [markdown]
# Noting that given observed info above about these dataframes, there appears to be:
# - one null value in the "Caffeine" column of the SBUX dataset.
# - no null values in the MCD dataset
#
# The following code formally assesses this by checking for missing values.

# %%
# checking for missing values
# True = missing values, False = no missing values

print(sbux.isnull().any().any())
# Out:
# True

# %%
# checking for missing values
# True = missing values, False = no missing values

print(mcd.isnull().any().any())
# Out:
# False

# %% [markdown]
# Checking for null values by column.

# %%
# counting the missing values per coulmn
sbux.isnull().sum()
# Out:
# Beverage_category            0
# Beverage_prep                0
# Calories                     0
#  Total Fat (g)               0
# Trans Fat (g)                0
# Saturated Fat (g)            0
#  Sodium (mg)                 0
#  Total Carbohydrates (g)     0
# Cholesterol (mg)             0
#  Dietary Fibre (g)           0
#  Sugars (g)                  0
#  Protein (g)                 0
# Vitamin A (% DV)             0
# Vitamin C (% DV)             0
#  Calcium (% DV)              0
# Iron (% DV)                  0
# Caffeine (mg)                1
# dtype: int64

# %%
# counting the missing values per coulmn
mcd.isnull().sum()
# Out:
# Category                         0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %% [markdown]
# Checking for null values by row.

# %%
# checking for rows with missing values
sbux.isnull().any(axis=1)
# Out:
# Beverage
# Brewed Coffee                                   False
# Brewed Coffee                                   False
# Brewed Coffee                                   False
# Brewed Coffee                                   False
# Caffè Latte                                     False
#                                                 ...
# Strawberries & Crème (Without Whipped Cream)    False
# Vanilla Bean (Without Whipped Cream)            False
# Vanilla Bean (Without Whipped Cream)            False
# Vanilla Bean (Without Whipped Cream)            False
# Vanilla Bean (Without Whipped Cream)            False
# Length: 242, dtype: bool

# %%
# checking for rows with missing values
mcd.isnull().any(axis=1)
# Out:
# Item
# Egg McMuffin                                         False
# Egg White Delight                                    False
# Sausage McMuffin                                     False
# Sausage McMuffin with Egg                            False
# Sausage McMuffin with Egg Whites                     False
#                                                      ...
# McFlurry with Oreo Cookies (Small)                   False
# McFlurry with Oreo Cookies (Medium)                  False
# McFlurry with Oreo Cookies (Snack)                   False
# McFlurry with Reese's Peanut Butter Cups (Medium)    False
# McFlurry with Reese's Peanut Butter Cups (Snack)     False
# Length: 260, dtype: bool

# %% [markdown]
# Previous observational findings (below) from review of the dataframe summary were confirmed:
# - one null value in the "Caffeine" column of the SBUX dataset.
# - no null values in the MCD dataset

# %% [markdown]
# The following code can be used to clarify which row in the "Caffeine" column contains the null value.

# %%
#checking for rows with null values using Boolean Series
null_caffeine = sbux[sbux.isnull().any(axis=1)]
print (null_caffeine)
# Out:
#                                                     Beverage_category  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)  Shaken Iced Beverages
#
#                                                Beverage_prep  Calories  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)       2% Milk        90
#
#                                                 Total Fat (g)  Trans Fat (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)              1            0.50
#
#                                                 Saturated Fat (g)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               0.00
#
#                                                  Sodium (mg)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)             5
#
#                                                  Total Carbohydrates (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                         25
#
#                                                 Cholesterol (mg)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                18
#
#                                                  Dietary Fibre (g)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                   0
#
#                                                  Sugars (g)   Protein (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)           18           2.00
#
#                                                Vitamin A (% DV)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                2%
#
#                                                Vitamin C (% DV)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               0%
#
#                                                 Calcium (% DV)  Iron (% DV)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               6%        0.00%
#
#                                                Caffeine (mg)
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)           NaN

# %% [markdown]
# Above code identifies that the index "Beverage" *Iced Brewed Coffee (With Milk & Classic Syrup)* with a "Beverage Prep" of *2% Milk* contains a null value in the "Caffeine" column.

# %% [markdown]
# Alternatively, the below code can identfy the specific index (indices) of this null value(s).

# %%
#checking indices of rows with null values
null_index = sbux.index[sbux.isnull().any(axis=1)].tolist()
print (null_index)
# Out:
# ['Iced Brewed Coffee (With Milk & Classic Syrup)']

# %% [markdown]
# This matches the above finding that the row for the "Beverage" *Iced Brewed Coffee (With Milk & Classic Syrup)* with a "Beverage Prep" of *2% Milk* contains a null value in the "Caffeine" column.

# %% [markdown]
# **Addreessing missing values**:
#
# It is important to determine how to address any null values in the dataframes.

# %% [markdown]
# **Note**: For these datasets, the null value is in the "*Caffeine*" column of the *SBUX* dataframe. While the plan is to *delete* this column, below is an example of how to address null values.

# %% [markdown]
# One option is to convert null values to zero.
#
# Teas were notable to have varianle caffeine intake and were also converted to zero.

# %%
# one missing value was identified in the SBUX dataset in a column which will later be deleted.
# for this dataset type, null value could be changed to 0 as per below, but I would have personally replaced missing values with the mean of similar beverages using the following code:

#verify data type
print(sbux["Caffeine (mg)"].dtype)
#change "Varies/ varies" to a null value
sbux["Caffeine (mg)"] = sbux["Caffeine (mg)"].replace("Varies", 0)
sbux["Caffeine (mg)"] = sbux["Caffeine (mg)"].replace("varies", 0)
#convert null value to 0
sbux["Caffeine (mg)"] = sbux["Caffeine (mg)"].fillna(0)
#verify conversion / check for null values in this column
print(sbux["Caffeine (mg)"].isnull().sum())
# Out:
# object
# 0

# %% [markdown]
# In this scenario where a distinction between the "Iced Brewed Coffee (with Milk & Classic Syrup) with non-null values and the one with a null value was the type of milk (which does not contain caffeine), using an average of similar drinks could be a better replacement but does not account for variation in cup size.
#
# Below is an example of another approach to replacing the null value. Again, this column will be deleted for the overall project.

# %%
#convert "Caffeine (mg)" column from object to integer
sbux["Caffeine (mg)"] = sbux["Caffeine (mg)"].astype(int)
#verify new column data type
print(sbux["Caffeine (mg)"].dtype)
# Out:
# int64

# %%
#determine mean "Caffeine (mg)" for Iced Brewed Coffee (With Milk & Classic Syrup)
similar_rows = sbux.loc["Iced Brewed Coffee (With Milk & Classic Syrup)"]
mean_caffeine = similar_rows['Caffeine (mg)'].mean()

print (mean_caffeine)
# Out:
# 109.44444444444444

# %%
# replace initial null value with mean "Caffeine (mg)" for similar beverages
sbux.loc[
    (sbux.index == "Iced Brewed Coffee (With Milk & Classic Syrup)") & (sbux["Beverage_prep"] == "2% Milk"),
    "Caffeine (mg)"
] = mean_caffeine
#verify change of initial null value
initial_null_row = sbux[
    (sbux.index == "Iced Brewed Coffee (With Milk & Classic Syrup)")  & (sbux["Beverage_prep"] == "2% Milk")
]
print(initial_null_row)
# Out:
#                                                     Beverage_category  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)  Shaken Iced Beverages
# Iced Brewed Coffee (With Milk & Classic Syrup)  Shaken Iced Beverages
# Iced Brewed Coffee (With Milk & Classic Syrup)  Shaken Iced Beverages
#
#                                                Beverage_prep  Calories  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)       2% Milk        90
# Iced Brewed Coffee (With Milk & Classic Syrup)       2% Milk       120
# Iced Brewed Coffee (With Milk & Classic Syrup)       2% Milk       180
#
#                                                 Total Fat (g)  Trans Fat (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)              1            0.50
# Iced Brewed Coffee (With Milk & Classic Syrup)            1.5            0.50
# Iced Brewed Coffee (With Milk & Classic Syrup)              2            1.00
#
#                                                 Saturated Fat (g)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               0.00
# Iced Brewed Coffee (With Milk & Classic Syrup)               0.00
# Iced Brewed Coffee (With Milk & Classic Syrup)               0.10
#
#                                                  Sodium (mg)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)             5
# Iced Brewed Coffee (With Milk & Classic Syrup)             5
# Iced Brewed Coffee (With Milk & Classic Syrup)            10
#
#                                                  Total Carbohydrates (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                         25
# Iced Brewed Coffee (With Milk & Classic Syrup)                         35
# Iced Brewed Coffee (With Milk & Classic Syrup)                         55
#
#                                                 Cholesterol (mg)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                18
# Iced Brewed Coffee (With Milk & Classic Syrup)                24
# Iced Brewed Coffee (With Milk & Classic Syrup)                36
#
#                                                  Dietary Fibre (g)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                   0
# Iced Brewed Coffee (With Milk & Classic Syrup)                   0
# Iced Brewed Coffee (With Milk & Classic Syrup)                   0
#
#                                                  Sugars (g)   Protein (g)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)           18           2.00
# Iced Brewed Coffee (With Milk & Classic Syrup)           24           2.00
# Iced Brewed Coffee (With Milk & Classic Syrup)           36           4.00
#
#                                                Vitamin A (% DV)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)                2%
# Iced Brewed Coffee (With Milk & Classic Syrup)                4%
# Iced Brewed Coffee (With Milk & Classic Syrup)                6%
#
#                                                Vitamin C (% DV)  \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               0%
# Iced Brewed Coffee (With Milk & Classic Syrup)               0%
# Iced Brewed Coffee (With Milk & Classic Syrup)               0%
#
#                                                 Calcium (% DV)  Iron (% DV)   \
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)               6%        0.00%
# Iced Brewed Coffee (With Milk & Classic Syrup)               8%           0%
# Iced Brewed Coffee (With Milk & Classic Syrup)              10%           0%
#
#                                                 Caffeine (mg)
# Beverage
# Iced Brewed Coffee (With Milk & Classic Syrup)         109.44
# Iced Brewed Coffee (With Milk & Classic Syrup)         109.44
# Iced Brewed Coffee (With Milk & Classic Syrup)         109.44
# /var/folders/p4/vp0c7k5558zdkk4sksrgx0fr0000gn/T/ipykernel_11275/3500505406.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '109.44444444444444' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   sbux.loc[

# %% [markdown]
# #### Dropping Rows

# %% [markdown]
# **Using Conditional Filtering to drop items from SBUX dataframe**

# %% [markdown]
# Removing rows from SBUX that do not correspond with MCD dataframe.

# %%
# checking starting dimensions for comparison;
df_shape = sbux.shape
print(f"The SBUX DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The SBUX DataFrame has 242 rows and 17 columns!

# %%
# identifying and dropping rows where "Beverage Prep" contains whole milk
sbux = sbux[sbux["Beverage_prep"] != "Whole Milk"]
# identifying and dropping rows where "Beverage Prep" contains soy milk
sbux = sbux[sbux["Beverage_prep"] != "Soymilk"]

# checking new dimensions
df_shape = sbux.shape
print(f"The SBUX DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The SBUX DataFrame has 160 rows and 17 columns!

# %% [markdown]
# Identified and dropped two irregular values in "Beverage Prep" column

# %%
print(sbux["Beverage_prep"].unique())
# Out:
# ['Short' 'Tall' 'Grande' 'Venti' 'Short Nonfat Milk' '2% Milk'
#  'Tall Nonfat Milk' 'Grande Nonfat Milk' 'Venti Nonfat Milk' 'Solo'
#  'Doppio']

# %%
# identifying and dropping rows where "Beverage Prep" contains Doppio
sbux = sbux[sbux["Beverage_prep"] != "Doppio"]
# identifying and dropping rows where "Beverage Prep" contains Solo
sbux = sbux[sbux["Beverage_prep"] != "Solo"]

# checking new dimensions
df_shape = sbux.shape
print(f"The SBUX DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The SBUX DataFrame has 158 rows and 17 columns!

# %% [markdown]
# Noting beverage types for comparison to MCD

# %%
sbux.value_counts("Beverage")
# Out:
# Beverage
# White Chocolate Mocha (Without Whipped Cream)          8
# Tazo® Green Tea Latte                                  8
# Tazo® Chai Tea Latte                                   8
# Caffè Latte                                            8
# Caffè Mocha (Without Whipped Cream)                    8
# Cappuccino                                             8
# Vanilla Latte (Or Other Flavoured Latte)               8
# Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)        8
# Tazo® Full-Leaf Tea Latte                              8
# Caramel Macchiato                                      8
# Hot Chocolate (Without Whipped Cream)                  8
# Iced Brewed Coffee (With Milk & Classic Syrup)         6
# Coffee                                                 6
# Caramel Apple Spice (Without Whipped Cream)            4
# Tazo® Tea                                              4
# Brewed Coffee                                          4
# Caffè Americano                                        4
# Skinny Latte (Any Flavour)                             4
# Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)    3
# Strawberries & Crème (Without Whipped Cream)           3
# Mocha                                                  3
# Shaken Iced Tazo® Tea (With Classic Syrup)             3
# Mocha (Without Whipped Cream)                          3
# Java Chip (Without Whipped Cream)                      3
# Java Chip                                              3
# Iced Brewed Coffee (With Classic Syrup)                3
# Caramel (Without Whipped Cream)                        3
# Caramel                                                3
# Orange Mango Banana Smoothie                           2
# Strawberry Banana Smoothie                             2
# Vanilla Bean (Without Whipped Cream)                   2
# Banana Chocolate Smoothie                              2
# Name: count, dtype: int64

# %%
print(sbux.index.unique())
# Out:
# Index(['Brewed Coffee', 'Caffè Latte', 'Caffè Mocha (Without Whipped Cream)',
#        'Vanilla Latte (Or Other Flavoured Latte)', 'Caffè Americano',
#        'Cappuccino', 'Skinny Latte (Any Flavour)', 'Caramel Macchiato',
#        'White Chocolate Mocha (Without Whipped Cream)',
#        'Hot Chocolate (Without Whipped Cream)',
#        'Caramel Apple Spice (Without Whipped Cream)', 'Tazo® Tea',
#        'Tazo® Chai Tea Latte', 'Tazo® Green Tea Latte',
#        'Tazo® Full-Leaf Tea Latte',
#        'Tazo® Full-Leaf Red Tea Latte (Vanilla Rooibos)',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Iced Brewed Coffee (With Milk & Classic Syrup)',
#        'Shaken Iced Tazo® Tea (With Classic Syrup)',
#        'Shaken Iced Tazo® Tea Lemonade (With Classic Syrup)',
#        'Banana Chocolate Smoothie', 'Orange Mango Banana Smoothie',
#        'Strawberry Banana Smoothie', 'Coffee', 'Mocha (Without Whipped Cream)',
#        'Caramel (Without Whipped Cream)', 'Java Chip (Without Whipped Cream)',
#        'Mocha', 'Caramel', 'Java Chip',
#        'Strawberries & Crème (Without Whipped Cream)',
#        'Vanilla Bean (Without Whipped Cream)'],
#       dtype='object', name='Beverage')

# %%
# assembling rows to drop
drop = sbux[sbux.index.str.contains(
    "Americano|Cappuccino|Lemonade|Strawberries & Crème|Tazo|Espresso|White Chocolate|Caramel Apple Spice|Orange Mango|Tea Latte|Banana Chocolate", 
    case=False,
    na=False)
    ]
# dropping rows using their index
sbux = sbux.drop(index=drop.index)

# checking new dimensions
df_shape = sbux.shape
print(f"The SBUX DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The SBUX DataFrame has 85 rows and 17 columns!

# %% [markdown]
# Remaining SBUX Beverage types

# %%
sbux.value_counts("Beverage")
print(sbux.index.unique())
# Out:
# Index(['Brewed Coffee', 'Caffè Latte', 'Caffè Mocha (Without Whipped Cream)',
#        'Vanilla Latte (Or Other Flavoured Latte)',
#        'Skinny Latte (Any Flavour)', 'Caramel Macchiato',
#        'Hot Chocolate (Without Whipped Cream)',
#        'Iced Brewed Coffee (With Classic Syrup)',
#        'Iced Brewed Coffee (With Milk & Classic Syrup)',
#        'Strawberry Banana Smoothie', 'Coffee', 'Mocha (Without Whipped Cream)',
#        'Caramel (Without Whipped Cream)', 'Java Chip (Without Whipped Cream)',
#        'Mocha', 'Caramel', 'Java Chip',
#        'Vanilla Bean (Without Whipped Cream)'],
#       dtype='object', name='Beverage')

# %% [markdown]
# Reviewing updated SBUX dataframe

# %%
sbux
# Out:
#                                                       Beverage_category  \
# Beverage
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Caffè Latte                                     Classic Espresso Drinks
# ...                                                                 ...
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
#
#                                            Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                                      Short         3
# Brewed Coffee                                       Tall         4
# Brewed Coffee                                     Grande         5
# Brewed Coffee                                      Venti         5
# Caffè Latte                            Short Nonfat Milk        70
# ...                                                  ...       ...
# Java Chip                               Tall Nonfat Milk       150
# Java Chip                             Grande Nonfat Milk       220
# Java Chip                              Venti Nonfat Milk       290
# Vanilla Bean (Without Whipped Cream)    Tall Nonfat Milk       170
# Vanilla Bean (Without Whipped Cream)  Grande Nonfat Milk       240
#
#                                       Total Fat (g)  Trans Fat (g)   \
# Beverage
# Brewed Coffee                                   0.1            0.00
# Brewed Coffee                                   0.1            0.00
# Brewed Coffee                                   0.1            0.00
# Brewed Coffee                                   0.1            0.00
# Caffè Latte                                     0.1            0.10
# ...                                             ...             ...
# Java Chip                                         3            2.00
# Java Chip                                         4            3.00
# Java Chip                                         5            4.00
# Vanilla Bean (Without Whipped Cream)            0.1            0.10
# Vanilla Bean (Without Whipped Cream)            0.1            0.10
#
#                                       Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Caffè Latte                                        0.00             5
# ...                                                 ...           ...
# Java Chip                                          0.00             0
# Java Chip                                          0.00             0
# Java Chip                                          0.00             5
# Vanilla Bean (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)               0.00             5
#
#                                        Total Carbohydrates (g)   \
# Beverage
# Brewed Coffee                                                 5
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Caffè Latte                                                  75
# ...                                                         ...
# Java Chip                                                   170
# Java Chip                                                   240
# Java Chip                                                   320
# Vanilla Bean (Without Whipped Cream)                        160
# Vanilla Bean (Without Whipped Cream)                        230
#
#                                       Cholesterol (mg)   Dietary Fibre (g)  \
# Beverage
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Caffè Latte                                         10                   0
# ...                                                ...                 ...
# Java Chip                                           30                   1
# Java Chip                                           43                   2
# Java Chip                                           58                   2
# Vanilla Bean (Without Whipped Cream)                39                   0
# Vanilla Bean (Without Whipped Cream)                56                   0
#
#                                        Sugars (g)   Protein (g)   \
# Beverage
# Brewed Coffee                                   0           0.30
# Brewed Coffee                                   0           0.50
# Brewed Coffee                                   0           1.00
# Brewed Coffee                                   0           1.00
# Caffè Latte                                     9           6.00
# ...                                           ...            ...
# Java Chip                                      27           4.00
# Java Chip                                      39           5.00
# Java Chip                                      52           7.00
# Vanilla Bean (Without Whipped Cream)           38           4.00
# Vanilla Bean (Without Whipped Cream)           55           5.00
#
#                                      Vitamin A (% DV)  Vitamin C (% DV)  \
# Beverage
# Brewed Coffee                                       0%               0%
# Brewed Coffee                                       0%               0%
# Brewed Coffee                                       0%               0%
# Brewed Coffee                                       0%               0%
# Caffè Latte                                        10%               0%
# ...                                                ...              ...
# Java Chip                                           4%               0%
# Java Chip                                           6%               0%
# Java Chip                                           8%               0%
# Vanilla Bean (Without Whipped Cream)                6%               0%
# Vanilla Bean (Without Whipped Cream)                8%               0%
#
#                                       Calcium (% DV)  Iron (% DV)   \
# Beverage
# Brewed Coffee                                      0%           0%
# Brewed Coffee                                      0%           0%
# Brewed Coffee                                      0%           0%
# Brewed Coffee                                      2%           0%
# Caffè Latte                                       20%           0%
# ...                                               ...          ...
# Java Chip                                         10%          20%
# Java Chip                                         10%          25%
# Java Chip                                         15%          35%
# Vanilla Bean (Without Whipped Cream)              10%           0%
# Vanilla Bean (Without Whipped Cream)              15%           0%
#
#                                       Caffeine (mg)
# Beverage
# Brewed Coffee                                175.00
# Brewed Coffee                                260.00
# Brewed Coffee                                330.00
# Brewed Coffee                                410.00
# Caffè Latte                                   75.00
# ...                                             ...
# Java Chip                                     70.00
# Java Chip                                    105.00
# Java Chip                                    165.00
# Vanilla Bean (Without Whipped Cream)           0.00
# Vanilla Bean (Without Whipped Cream)           0.00
#
# [85 rows x 17 columns]

# %% [markdown]
# **Using Indexing to drop items from MCD dataframe**

# %%
mcd.value_counts("Item")
# Out:
# Item
# 1% Low Fat Milk Jug                  1
# Minute Maid Orange Juice (Medium)    1
# Mocha (Large)                        1
# Mocha (Medium)                       1
# Mocha (Small)                        1
#                                     ..
# French Vanilla Latte (Large)         1
# French Vanilla Latte (Medium)        1
# French Vanilla Latte (Small)         1
# Fruit & Maple Oatmeal                1
# Vanilla Shake (Small)                1
# Name: count, Length: 260, dtype: int64

# %%
# checking starting dimensions for comparison;
df_shape = mcd.shape
print(f"The MCD DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The MCD DataFrame has 260 rows and 23 columns!

# %% [markdown]
# Assessing types of categories

# %%
mcd.value_counts("Category")
# Out:
# Category
# Coffee & Tea          95
# Breakfast             42
# Smoothies & Shakes    28
# Beverages             27
# Chicken & Fish        27
# Beef & Pork           15
# Snacks & Sides        13
# Desserts               7
# Salads                 6
# Name: count, dtype: int64

# %% [markdown]
# Removing categories for food items and sodas

# %%
# identifying rows where "Category" is a food item or soda
# identifying categories  to drop
food_soda = ["Breakfast","Beef & Pork","Chicken & Fish","Salads","Snacks & Sides","Desserts","Beverages"]
# creating index of rows to drop
foods = mcd[mcd["Category"].isin(food_soda)].index
# dropping rows using their index
mcd = mcd.drop(index=foods)

# checking new dimensions
df_shape = mcd.shape
print(f"The MCD DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The MCD DataFrame has 123 rows and 23 columns!

# %% [markdown]
# Removing rows from MCD that do not  correspond with SBUX dataframe.

# %%
# creating index of rows to drop
shakes = mcd[mcd.index.str.contains("McFlurry|Shake|Blueberry Pomegranate|Mango Pineapple|Hazelnut|Sweet tea", case=False)].index
# dropping rows using their index
mcd = mcd.drop(index=shakes)

# checking new dimensions
df_shape = mcd.shape
print(f"The MCD DataFrame has {df_shape[0]} rows and {df_shape[1]} columns!")
# Out:
# The MCD DataFrame has 85 rows and 23 columns!

# %% [markdown]
# Reviewing updated MCD dataframe

# %%
mcd
# Out:
#                                                Category  Serving Size  \
# Item
# Iced Tea (Small)                           Coffee & Tea  16 fl oz cup
# Iced Tea (Medium)                          Coffee & Tea  21 fl oz cup
# Iced Tea (Large)                           Coffee & Tea  30 fl oz cup
# Iced Tea (Child)                           Coffee & Tea  12 fl oz cup
# Coffee (Small)                             Coffee & Tea  12 fl oz cup
# ...                                                 ...           ...
# Frappé Chocolate Chip (Medium)             Coffee & Tea  16 fl oz cup
# Frappé Chocolate Chip (Large)              Coffee & Tea  22 fl oz cup
# Strawberry Banana Smoothie (Small)   Smoothies & Shakes  12 fl oz cup
# Strawberry Banana Smoothie (Medium)  Smoothies & Shakes  16 fl oz cup
# Strawberry Banana Smoothie (Large)   Smoothies & Shakes  22 fl oz cup
#
#                                      Calories  Calories from Fat  Total Fat  \
# Item
# Iced Tea (Small)                            0                  0       0.00
# Iced Tea (Medium)                           0                  0       0.00
# Iced Tea (Large)                            0                  0       0.00
# Iced Tea (Child)                            0                  0       0.00
# Coffee (Small)                              0                  0       0.00
# ...                                       ...                ...        ...
# Frappé Chocolate Chip (Medium)            630                240      26.00
# Frappé Chocolate Chip (Large)             760                280      31.00
# Strawberry Banana Smoothie (Small)        210                  5       0.50
# Strawberry Banana Smoothie (Medium)       250                  5       1.00
# Strawberry Banana Smoothie (Large)        330                 10       1.00
#
#                                      Total Fat (% Daily Value)  Saturated Fat  \
# Item
# Iced Tea (Small)                                             0           0.00
# Iced Tea (Medium)                                            0           0.00
# Iced Tea (Large)                                             0           0.00
# Iced Tea (Child)                                             0           0.00
# Coffee (Small)                                               0           0.00
# ...                                                        ...            ...
# Frappé Chocolate Chip (Medium)                              41          17.00
# Frappé Chocolate Chip (Large)                               48          20.00
# Strawberry Banana Smoothie (Small)                           1           0.00
# Strawberry Banana Smoothie (Medium)                          1           0.00
# Strawberry Banana Smoothie (Large)                           2           0.50
#
#                                      Saturated Fat (% Daily Value)  Trans Fat  \
# Item
# Iced Tea (Small)                                                 0       0.00
# Iced Tea (Medium)                                                0       0.00
# Iced Tea (Large)                                                 0       0.00
# Iced Tea (Child)                                                 0       0.00
# Coffee (Small)                                                   0       0.00
# ...                                                            ...        ...
# Frappé Chocolate Chip (Medium)                                  85       1.00
# Frappé Chocolate Chip (Large)                                  101       1.50
# Strawberry Banana Smoothie (Small)                               0       0.00
# Strawberry Banana Smoothie (Medium)                              0       0.00
# Strawberry Banana Smoothie (Large)                               3       0.00
#
#                                      Cholesterol  ...  Carbohydrates  \
# Item                                              ...
# Iced Tea (Small)                               0  ...              0
# Iced Tea (Medium)                              0  ...              0
# Iced Tea (Large)                               0  ...              0
# Iced Tea (Child)                               0  ...              0
# Coffee (Small)                                 0  ...              0
# ...                                          ...  ...            ...
# Frappé Chocolate Chip (Medium)                80  ...             91
# Frappé Chocolate Chip (Large)                 95  ...            111
# Strawberry Banana Smoothie (Small)             5  ...             47
# Strawberry Banana Smoothie (Medium)            5  ...             58
# Strawberry Banana Smoothie (Large)             5  ...             74
#
#                                      Carbohydrates (% Daily Value)  \
# Item
# Iced Tea (Small)                                                 0
# Iced Tea (Medium)                                                0
# Iced Tea (Large)                                                 0
# Iced Tea (Child)                                                 0
# Coffee (Small)                                                   0
# ...                                                            ...
# Frappé Chocolate Chip (Medium)                                  30
# Frappé Chocolate Chip (Large)                                   37
# Strawberry Banana Smoothie (Small)                              16
# Strawberry Banana Smoothie (Medium)                             19
# Strawberry Banana Smoothie (Large)                              25
#
#                                      Dietary Fiber  \
# Item
# Iced Tea (Small)                                 0
# Iced Tea (Medium)                                0
# Iced Tea (Large)                                 0
# Iced Tea (Child)                                 0
# Coffee (Small)                                   0
# ...                                            ...
# Frappé Chocolate Chip (Medium)                   1
# Frappé Chocolate Chip (Large)                    1
# Strawberry Banana Smoothie (Small)               3
# Strawberry Banana Smoothie (Medium)              3
# Strawberry Banana Smoothie (Large)               4
#
#                                      Dietary Fiber (% Daily Value)  Sugars  \
# Item
# Iced Tea (Small)                                                 0       0
# Iced Tea (Medium)                                                0       0
# Iced Tea (Large)                                                 0       0
# Iced Tea (Child)                                                 0       0
# Coffee (Small)                                                   0       0
# ...                                                            ...     ...
# Frappé Chocolate Chip (Medium)                                   5      81
# Frappé Chocolate Chip (Large)                                    5      99
# Strawberry Banana Smoothie (Small)                              10      44
# Strawberry Banana Smoothie (Medium)                             13      54
# Strawberry Banana Smoothie (Large)                              16      70
#
#                                      Protein  Vitamin A (% Daily Value)  \
# Item
# Iced Tea (Small)                           0                          0
# Iced Tea (Medium)                          0                          0
# Iced Tea (Large)                           0                          0
# Iced Tea (Child)                           0                          0
# Coffee (Small)                             0                          0
# ...                                      ...                        ...
# Frappé Chocolate Chip (Medium)             9                         15
# Frappé Chocolate Chip (Large)             12                         20
# Strawberry Banana Smoothie (Small)         3                          0
# Strawberry Banana Smoothie (Medium)        4                          0
# Strawberry Banana Smoothie (Large)         5                          0
#
#                                      Vitamin C (% Daily Value)  \
# Item
# Iced Tea (Small)                                             0
# Iced Tea (Medium)                                            0
# Iced Tea (Large)                                             0
# Iced Tea (Child)                                             0
# Coffee (Small)                                               0
# ...                                                        ...
# Frappé Chocolate Chip (Medium)                               0
# Frappé Chocolate Chip (Large)                                0
# Strawberry Banana Smoothie (Small)                          30
# Strawberry Banana Smoothie (Medium)                         35
# Strawberry Banana Smoothie (Large)                          45
#
#                                      Calcium (% Daily Value)  \
# Item
# Iced Tea (Small)                                           0
# Iced Tea (Medium)                                          0
# Iced Tea (Large)                                           0
# Iced Tea (Child)                                           0
# Coffee (Small)                                             0
# ...                                                      ...
# Frappé Chocolate Chip (Medium)                            30
# Frappé Chocolate Chip (Large)                             35
# Strawberry Banana Smoothie (Small)                         8
# Strawberry Banana Smoothie (Medium)                        8
# Strawberry Banana Smoothie (Large)                        10
#
#                                      Iron (% Daily Value)
# Item
# Iced Tea (Small)                                        0
# Iced Tea (Medium)                                       0
# Iced Tea (Large)                                        0
# Iced Tea (Child)                                        0
# Coffee (Small)                                          0
# ...                                                   ...
# Frappé Chocolate Chip (Medium)                          4
# Frappé Chocolate Chip (Large)                           6
# Strawberry Banana Smoothie (Small)                      2
# Strawberry Banana Smoothie (Medium)                     4
# Strawberry Banana Smoothie (Large)                      4
#
# [85 rows x 23 columns]

# %% [markdown]
# #### Dropping Columns
#
# Based on analysis of data above, the following columns were noted to be eligible for dropping:
# - Caffeine (SBUX)
# - Calories from Fat (MCD)
# - % Daily Value of: Total Fat, Saturated Fat, Cholesterol, Sodium, Carbohydrates, Dietary Fiber (MCD)

# %% [markdown]
# **Dropping an indiviual column**

# %%
# dropping the 'Caffeine (mg)' column from the SBUX dataframe
sbux.drop('Caffeine (mg)', axis=1, inplace=True)
# verifying remaining columns:
# displaying column names
sbux.columns
# displaying column names in list form
list(sbux.columns)
# Out:
# ['Beverage_category',
#  'Beverage_prep',
#  'Calories',
#  ' Total Fat (g)',
#  'Trans Fat (g) ',
#  'Saturated Fat (g)',
#  ' Sodium (mg)',
#  ' Total Carbohydrates (g) ',
#  'Cholesterol (mg)',
#  ' Dietary Fibre (g)',
#  ' Sugars (g)',
#  ' Protein (g) ',
#  'Vitamin A (% DV) ',
#  'Vitamin C (% DV)',
#  ' Calcium (% DV) ',
#  'Iron (% DV) ']

# %% [markdown]
# **Dropping multiple columns as a list**

# %%
# dropping the 'Calories from Fat', 'Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)', 'Cholesterol (% Daily Value)',  'Sodium (% Daily Value)', 'Carbohydrates (% Daily Value)', & 'Dietary Fiber (% Daily Value)' columns from the MCD dataframe
droplist = ['Calories from Fat', 'Total Fat (% Daily Value)', 'Saturated Fat (% Daily Value)', 'Cholesterol (% Daily Value)',  'Sodium (% Daily Value)', 'Carbohydrates (% Daily Value)', 'Dietary Fiber (% Daily Value)']
mcd = mcd.drop(columns = droplist)  
# verifying remaining columns:
# displaying column names
mcd.columns
# displaying column names in list form
list(mcd.columns)
# Out:
# ['Category',
#  'Serving Size',
#  'Calories',
#  'Total Fat',
#  'Saturated Fat',
#  'Trans Fat',
#  'Cholesterol',
#  'Sodium',
#  'Carbohydrates',
#  'Dietary Fiber',
#  'Sugars',
#  'Protein',
#  'Vitamin A (% Daily Value)',
#  'Vitamin C (% Daily Value)',
#  'Calcium (% Daily Value)',
#  'Iron (% Daily Value)']

# %% [markdown]
# ### Data Preparation

# %% [markdown]
# #### Modifying Column Datatype
#
# **Refresher of datatype of remaining columns**

# %%
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for fit of asssigned data types
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          85 non-null     object
#  1   Beverage_prep              85 non-null     object
#  2   Calories                   85 non-null     int64
#  3    Total Fat (g)             85 non-null     object
#  4   Trans Fat (g)              85 non-null     float64
#  5   Saturated Fat (g)          85 non-null     float64
#  6    Sodium (mg)               85 non-null     int64
#  7    Total Carbohydrates (g)   85 non-null     int64
#  8   Cholesterol (mg)           85 non-null     int64
#  9    Dietary Fibre (g)         85 non-null     int64
#  10   Sugars (g)                85 non-null     int64
#  11   Protein (g)               85 non-null     float64
#  12  Vitamin A (% DV)           85 non-null     object
#  13  Vitamin C (% DV)           85 non-null     object
#  14   Calcium (% DV)            85 non-null     object
#  15  Iron (% DV)                85 non-null     object
# dtypes: float64(3), int64(6), object(7)
# memory usage: 13.3+ KB

# %%
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for fit of asssigned data types
mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Iced Tea (Small) to Strawberry Banana Smoothie (Large)
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Category                   85 non-null     object
#  1   Serving Size               85 non-null     object
#  2   Calories                   85 non-null     int64
#  3   Total Fat                  85 non-null     float64
#  4   Saturated Fat              85 non-null     float64
#  5   Trans Fat                  85 non-null     float64
#  6   Cholesterol                85 non-null     int64
#  7   Sodium                     85 non-null     int64
#  8   Carbohydrates              85 non-null     int64
#  9   Dietary Fiber              85 non-null     int64
#  10  Sugars                     85 non-null     int64
#  11  Protein                    85 non-null     int64
#  12  Vitamin A (% Daily Value)  85 non-null     int64
#  13  Vitamin C (% Daily Value)  85 non-null     int64
#  14  Calcium (% Daily Value)    85 non-null     int64
#  15  Iron (% Daily Value)       85 non-null     int64
# dtypes: float64(3), int64(11), object(2)
# memory usage: 11.3+ KB

# %% [markdown]
# **Data Type Adjustments**

# %% [markdown]
# For SBUX to match MCD,
# - total fat and %DV columns need to be converted to float
# - protein column needs to be converted to int.

# %%
print(sbux.columns)
# Out:
# Index(['Beverage_category', 'Beverage_prep', 'Calories', ' Total Fat (g)',
#        'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) '],
#       dtype='object')

# %% [markdown]
# *Changing objects to floats*

# %%
# changing datatype
sbux[" Total Fat (g)"] = sbux[" Total Fat (g)"].astype(float)

# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for fit of asssigned data types
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          85 non-null     object
#  1   Beverage_prep              85 non-null     object
#  2   Calories                   85 non-null     int64
#  3    Total Fat (g)             85 non-null     float64
#  4   Trans Fat (g)              85 non-null     float64
#  5   Saturated Fat (g)          85 non-null     float64
#  6    Sodium (mg)               85 non-null     int64
#  7    Total Carbohydrates (g)   85 non-null     int64
#  8   Cholesterol (mg)           85 non-null     int64
#  9    Dietary Fibre (g)         85 non-null     int64
#  10   Sugars (g)                85 non-null     int64
#  11   Protein (g)               85 non-null     float64
#  12  Vitamin A (% DV)           85 non-null     object
#  13  Vitamin C (% DV)           85 non-null     object
#  14   Calcium (% DV)            85 non-null     object
#  15  Iron (% DV)                85 non-null     object
# dtypes: float64(4), int64(6), object(6)
# memory usage: 13.3+ KB

# %% [markdown]
# *Changing floats to integers*

# %%
# changing datatype
sbux[" Protein (g) "] = sbux[" Protein (g) "].astype(int)

# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for fit of asssigned data types
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          85 non-null     object
#  1   Beverage_prep              85 non-null     object
#  2   Calories                   85 non-null     int64
#  3    Total Fat (g)             85 non-null     float64
#  4   Trans Fat (g)              85 non-null     float64
#  5   Saturated Fat (g)          85 non-null     float64
#  6    Sodium (mg)               85 non-null     int64
#  7    Total Carbohydrates (g)   85 non-null     int64
#  8   Cholesterol (mg)           85 non-null     int64
#  9    Dietary Fibre (g)         85 non-null     int64
#  10   Sugars (g)                85 non-null     int64
#  11   Protein (g)               85 non-null     int64
#  12  Vitamin A (% DV)           85 non-null     object
#  13  Vitamin C (% DV)           85 non-null     object
#  14   Calcium (% DV)            85 non-null     object
#  15  Iron (% DV)                85 non-null     object
# dtypes: float64(3), int64(7), object(6)
# memory usage: 13.3+ KB

# %% [markdown]
# *Chaging objects to integers* (requires conversion to float first)

# %%
# changing datatype
conversions = [' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
       ' Calcium (% DV) ', 'Iron (% DV) ']
sbux[conversions] = sbux[conversions].replace("%","", regex=True).astype(float).astype(int)

# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for fit of asssigned data types
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 16 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          85 non-null     object
#  1   Beverage_prep              85 non-null     object
#  2   Calories                   85 non-null     int64
#  3    Total Fat (g)             85 non-null     float64
#  4   Trans Fat (g)              85 non-null     float64
#  5   Saturated Fat (g)          85 non-null     float64
#  6    Sodium (mg)               85 non-null     int64
#  7    Total Carbohydrates (g)   85 non-null     int64
#  8   Cholesterol (mg)           85 non-null     int64
#  9    Dietary Fibre (g)         85 non-null     int64
#  10   Sugars (g)                85 non-null     int64
#  11   Protein (g)               85 non-null     int64
#  12  Vitamin A (% DV)           85 non-null     int64
#  13  Vitamin C (% DV)           85 non-null     int64
#  14   Calcium (% DV)            85 non-null     int64
#  15  Iron (% DV)                85 non-null     int64
# dtypes: float64(3), int64(11), object(2)
# memory usage: 13.3+ KB

# %% [markdown]
# #### Feature Engineering

# %% [markdown]
# Reviewing updated dataframes

# %%
sbux
# Out:
#                                                       Beverage_category  \
# Beverage
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Caffè Latte                                     Classic Espresso Drinks
# ...                                                                 ...
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
#
#                                            Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                                      Short         3
# Brewed Coffee                                       Tall         4
# Brewed Coffee                                     Grande         5
# Brewed Coffee                                      Venti         5
# Caffè Latte                            Short Nonfat Milk        70
# ...                                                  ...       ...
# Java Chip                               Tall Nonfat Milk       150
# Java Chip                             Grande Nonfat Milk       220
# Java Chip                              Venti Nonfat Milk       290
# Vanilla Bean (Without Whipped Cream)    Tall Nonfat Milk       170
# Vanilla Bean (Without Whipped Cream)  Grande Nonfat Milk       240
#
#                                        Total Fat (g)  Trans Fat (g)   \
# Beverage
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Caffè Latte                                     0.10            0.10
# ...                                              ...             ...
# Java Chip                                       3.00            2.00
# Java Chip                                       4.00            3.00
# Java Chip                                       5.00            4.00
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
#
#                                       Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Caffè Latte                                        0.00             5
# ...                                                 ...           ...
# Java Chip                                          0.00             0
# Java Chip                                          0.00             0
# Java Chip                                          0.00             5
# Vanilla Bean (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)               0.00             5
#
#                                        Total Carbohydrates (g)   \
# Beverage
# Brewed Coffee                                                 5
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Caffè Latte                                                  75
# ...                                                         ...
# Java Chip                                                   170
# Java Chip                                                   240
# Java Chip                                                   320
# Vanilla Bean (Without Whipped Cream)                        160
# Vanilla Bean (Without Whipped Cream)                        230
#
#                                       Cholesterol (mg)   Dietary Fibre (g)  \
# Beverage
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Caffè Latte                                         10                   0
# ...                                                ...                 ...
# Java Chip                                           30                   1
# Java Chip                                           43                   2
# Java Chip                                           58                   2
# Vanilla Bean (Without Whipped Cream)                39                   0
# Vanilla Bean (Without Whipped Cream)                56                   0
#
#                                        Sugars (g)   Protein (g)   \
# Beverage
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              1
# Brewed Coffee                                   0              1
# Caffè Latte                                     9              6
# ...                                           ...            ...
# Java Chip                                      27              4
# Java Chip                                      39              5
# Java Chip                                      52              7
# Vanilla Bean (Without Whipped Cream)           38              4
# Vanilla Bean (Without Whipped Cream)           55              5
#
#                                       Vitamin A (% DV)   Vitamin C (% DV)  \
# Beverage
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Caffè Latte                                          10                 0
# ...                                                 ...               ...
# Java Chip                                             4                 0
# Java Chip                                             6                 0
# Java Chip                                             8                 0
# Vanilla Bean (Without Whipped Cream)                  6                 0
# Vanilla Bean (Without Whipped Cream)                  8                 0
#
#                                        Calcium (% DV)   Iron (% DV)
# Beverage
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        2             0
# Caffè Latte                                         20             0
# ...                                                ...           ...
# Java Chip                                           10            20
# Java Chip                                           10            25
# Java Chip                                           15            35
# Vanilla Bean (Without Whipped Cream)                10             0
# Vanilla Bean (Without Whipped Cream)                15             0
#
# [85 rows x 16 columns]

# %%
mcd
# Out:
#                                                Category  Serving Size  \
# Item
# Iced Tea (Small)                           Coffee & Tea  16 fl oz cup
# Iced Tea (Medium)                          Coffee & Tea  21 fl oz cup
# Iced Tea (Large)                           Coffee & Tea  30 fl oz cup
# Iced Tea (Child)                           Coffee & Tea  12 fl oz cup
# Coffee (Small)                             Coffee & Tea  12 fl oz cup
# ...                                                 ...           ...
# Frappé Chocolate Chip (Medium)             Coffee & Tea  16 fl oz cup
# Frappé Chocolate Chip (Large)              Coffee & Tea  22 fl oz cup
# Strawberry Banana Smoothie (Small)   Smoothies & Shakes  12 fl oz cup
# Strawberry Banana Smoothie (Medium)  Smoothies & Shakes  16 fl oz cup
# Strawberry Banana Smoothie (Large)   Smoothies & Shakes  22 fl oz cup
#
#                                      Calories  Total Fat  Saturated Fat  \
# Item
# Iced Tea (Small)                            0       0.00           0.00
# Iced Tea (Medium)                           0       0.00           0.00
# Iced Tea (Large)                            0       0.00           0.00
# Iced Tea (Child)                            0       0.00           0.00
# Coffee (Small)                              0       0.00           0.00
# ...                                       ...        ...            ...
# Frappé Chocolate Chip (Medium)            630      26.00          17.00
# Frappé Chocolate Chip (Large)             760      31.00          20.00
# Strawberry Banana Smoothie (Small)        210       0.50           0.00
# Strawberry Banana Smoothie (Medium)       250       1.00           0.00
# Strawberry Banana Smoothie (Large)        330       1.00           0.50
#
#                                      Trans Fat  Cholesterol  Sodium  \
# Item
# Iced Tea (Small)                          0.00            0      10
# Iced Tea (Medium)                         0.00            0      10
# Iced Tea (Large)                          0.00            0      15
# Iced Tea (Child)                          0.00            0       5
# Coffee (Small)                            0.00            0       0
# ...                                        ...          ...     ...
# Frappé Chocolate Chip (Medium)            1.00           80     160
# Frappé Chocolate Chip (Large)             1.50           95     200
# Strawberry Banana Smoothie (Small)        0.00            5      50
# Strawberry Banana Smoothie (Medium)       0.00            5      60
# Strawberry Banana Smoothie (Large)        0.00            5      80
#
#                                      Carbohydrates  Dietary Fiber  Sugars  \
# Item
# Iced Tea (Small)                                 0              0       0
# Iced Tea (Medium)                                0              0       0
# Iced Tea (Large)                                 0              0       0
# Iced Tea (Child)                                 0              0       0
# Coffee (Small)                                   0              0       0
# ...                                            ...            ...     ...
# Frappé Chocolate Chip (Medium)                  91              1      81
# Frappé Chocolate Chip (Large)                  111              1      99
# Strawberry Banana Smoothie (Small)              47              3      44
# Strawberry Banana Smoothie (Medium)             58              3      54
# Strawberry Banana Smoothie (Large)              74              4      70
#
#                                      Protein  Vitamin A (% Daily Value)  \
# Item
# Iced Tea (Small)                           0                          0
# Iced Tea (Medium)                          0                          0
# Iced Tea (Large)                           0                          0
# Iced Tea (Child)                           0                          0
# Coffee (Small)                             0                          0
# ...                                      ...                        ...
# Frappé Chocolate Chip (Medium)             9                         15
# Frappé Chocolate Chip (Large)             12                         20
# Strawberry Banana Smoothie (Small)         3                          0
# Strawberry Banana Smoothie (Medium)        4                          0
# Strawberry Banana Smoothie (Large)         5                          0
#
#                                      Vitamin C (% Daily Value)  \
# Item
# Iced Tea (Small)                                             0
# Iced Tea (Medium)                                            0
# Iced Tea (Large)                                             0
# Iced Tea (Child)                                             0
# Coffee (Small)                                               0
# ...                                                        ...
# Frappé Chocolate Chip (Medium)                               0
# Frappé Chocolate Chip (Large)                                0
# Strawberry Banana Smoothie (Small)                          30
# Strawberry Banana Smoothie (Medium)                         35
# Strawberry Banana Smoothie (Large)                          45
#
#                                      Calcium (% Daily Value)  \
# Item
# Iced Tea (Small)                                           0
# Iced Tea (Medium)                                          0
# Iced Tea (Large)                                           0
# Iced Tea (Child)                                           0
# Coffee (Small)                                             0
# ...                                                      ...
# Frappé Chocolate Chip (Medium)                            30
# Frappé Chocolate Chip (Large)                             35
# Strawberry Banana Smoothie (Small)                         8
# Strawberry Banana Smoothie (Medium)                        8
# Strawberry Banana Smoothie (Large)                        10
#
#                                      Iron (% Daily Value)
# Item
# Iced Tea (Small)                                        0
# Iced Tea (Medium)                                       0
# Iced Tea (Large)                                        0
# Iced Tea (Child)                                        0
# Coffee (Small)                                          0
# ...                                                   ...
# Frappé Chocolate Chip (Medium)                          4
# Frappé Chocolate Chip (Large)                           6
# Strawberry Banana Smoothie (Small)                      2
# Strawberry Banana Smoothie (Medium)                     4
# Strawberry Banana Smoothie (Large)                      4
#
# [85 rows x 16 columns]

# %% [markdown]
# **Standardizing similar Beverages / Items with differing names**

# %%
#Adding "Frap" to "Beverage prep" for "Beverage Category" that lists Frappuccino
sbux.loc[sbux["Beverage_category"].str.contains("Frappuccino", case=False), "Beverage_prep"] += " Frap"

sbux
# Out:
#                                                       Beverage_category  \
# Beverage
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Caffè Latte                                     Classic Espresso Drinks
# ...                                                                 ...
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
#
#                                                 Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                                           Short         3
# Brewed Coffee                                            Tall         4
# Brewed Coffee                                          Grande         5
# Brewed Coffee                                           Venti         5
# Caffè Latte                                 Short Nonfat Milk        70
# ...                                                       ...       ...
# Java Chip                               Tall Nonfat Milk Frap       150
# Java Chip                             Grande Nonfat Milk Frap       220
# Java Chip                              Venti Nonfat Milk Frap       290
# Vanilla Bean (Without Whipped Cream)    Tall Nonfat Milk Frap       170
# Vanilla Bean (Without Whipped Cream)  Grande Nonfat Milk Frap       240
#
#                                        Total Fat (g)  Trans Fat (g)   \
# Beverage
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Caffè Latte                                     0.10            0.10
# ...                                              ...             ...
# Java Chip                                       3.00            2.00
# Java Chip                                       4.00            3.00
# Java Chip                                       5.00            4.00
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
#
#                                       Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Caffè Latte                                        0.00             5
# ...                                                 ...           ...
# Java Chip                                          0.00             0
# Java Chip                                          0.00             0
# Java Chip                                          0.00             5
# Vanilla Bean (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)               0.00             5
#
#                                        Total Carbohydrates (g)   \
# Beverage
# Brewed Coffee                                                 5
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Caffè Latte                                                  75
# ...                                                         ...
# Java Chip                                                   170
# Java Chip                                                   240
# Java Chip                                                   320
# Vanilla Bean (Without Whipped Cream)                        160
# Vanilla Bean (Without Whipped Cream)                        230
#
#                                       Cholesterol (mg)   Dietary Fibre (g)  \
# Beverage
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Caffè Latte                                         10                   0
# ...                                                ...                 ...
# Java Chip                                           30                   1
# Java Chip                                           43                   2
# Java Chip                                           58                   2
# Vanilla Bean (Without Whipped Cream)                39                   0
# Vanilla Bean (Without Whipped Cream)                56                   0
#
#                                        Sugars (g)   Protein (g)   \
# Beverage
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              1
# Brewed Coffee                                   0              1
# Caffè Latte                                     9              6
# ...                                           ...            ...
# Java Chip                                      27              4
# Java Chip                                      39              5
# Java Chip                                      52              7
# Vanilla Bean (Without Whipped Cream)           38              4
# Vanilla Bean (Without Whipped Cream)           55              5
#
#                                       Vitamin A (% DV)   Vitamin C (% DV)  \
# Beverage
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Caffè Latte                                          10                 0
# ...                                                 ...               ...
# Java Chip                                             4                 0
# Java Chip                                             6                 0
# Java Chip                                             8                 0
# Vanilla Bean (Without Whipped Cream)                  6                 0
# Vanilla Bean (Without Whipped Cream)                  8                 0
#
#                                        Calcium (% DV)   Iron (% DV)
# Beverage
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        2             0
# Caffè Latte                                         20             0
# ...                                                ...           ...
# Java Chip                                           10            20
# Java Chip                                           10            25
# Java Chip                                           15            35
# Vanilla Bean (Without Whipped Cream)                10             0
# Vanilla Bean (Without Whipped Cream)                15             0
#
# [85 rows x 16 columns]

# %%
#Adding "Frap" to "Serving Size" for "Item" that lists Frappe
mcd.loc[mcd.index.str.contains("Frappé", case=False), "Serving Size"] += " Frap"

mcd
# Out:
#                                                Category       Serving Size  \
# Item
# Iced Tea (Small)                           Coffee & Tea       16 fl oz cup
# Iced Tea (Medium)                          Coffee & Tea       21 fl oz cup
# Iced Tea (Large)                           Coffee & Tea       30 fl oz cup
# Iced Tea (Child)                           Coffee & Tea       12 fl oz cup
# Coffee (Small)                             Coffee & Tea       12 fl oz cup
# ...                                                 ...                ...
# Frappé Chocolate Chip (Medium)             Coffee & Tea  16 fl oz cup Frap
# Frappé Chocolate Chip (Large)              Coffee & Tea  22 fl oz cup Frap
# Strawberry Banana Smoothie (Small)   Smoothies & Shakes       12 fl oz cup
# Strawberry Banana Smoothie (Medium)  Smoothies & Shakes       16 fl oz cup
# Strawberry Banana Smoothie (Large)   Smoothies & Shakes       22 fl oz cup
#
#                                      Calories  Total Fat  Saturated Fat  \
# Item
# Iced Tea (Small)                            0       0.00           0.00
# Iced Tea (Medium)                           0       0.00           0.00
# Iced Tea (Large)                            0       0.00           0.00
# Iced Tea (Child)                            0       0.00           0.00
# Coffee (Small)                              0       0.00           0.00
# ...                                       ...        ...            ...
# Frappé Chocolate Chip (Medium)            630      26.00          17.00
# Frappé Chocolate Chip (Large)             760      31.00          20.00
# Strawberry Banana Smoothie (Small)        210       0.50           0.00
# Strawberry Banana Smoothie (Medium)       250       1.00           0.00
# Strawberry Banana Smoothie (Large)        330       1.00           0.50
#
#                                      Trans Fat  Cholesterol  Sodium  \
# Item
# Iced Tea (Small)                          0.00            0      10
# Iced Tea (Medium)                         0.00            0      10
# Iced Tea (Large)                          0.00            0      15
# Iced Tea (Child)                          0.00            0       5
# Coffee (Small)                            0.00            0       0
# ...                                        ...          ...     ...
# Frappé Chocolate Chip (Medium)            1.00           80     160
# Frappé Chocolate Chip (Large)             1.50           95     200
# Strawberry Banana Smoothie (Small)        0.00            5      50
# Strawberry Banana Smoothie (Medium)       0.00            5      60
# Strawberry Banana Smoothie (Large)        0.00            5      80
#
#                                      Carbohydrates  Dietary Fiber  Sugars  \
# Item
# Iced Tea (Small)                                 0              0       0
# Iced Tea (Medium)                                0              0       0
# Iced Tea (Large)                                 0              0       0
# Iced Tea (Child)                                 0              0       0
# Coffee (Small)                                   0              0       0
# ...                                            ...            ...     ...
# Frappé Chocolate Chip (Medium)                  91              1      81
# Frappé Chocolate Chip (Large)                  111              1      99
# Strawberry Banana Smoothie (Small)              47              3      44
# Strawberry Banana Smoothie (Medium)             58              3      54
# Strawberry Banana Smoothie (Large)              74              4      70
#
#                                      Protein  Vitamin A (% Daily Value)  \
# Item
# Iced Tea (Small)                           0                          0
# Iced Tea (Medium)                          0                          0
# Iced Tea (Large)                           0                          0
# Iced Tea (Child)                           0                          0
# Coffee (Small)                             0                          0
# ...                                      ...                        ...
# Frappé Chocolate Chip (Medium)             9                         15
# Frappé Chocolate Chip (Large)             12                         20
# Strawberry Banana Smoothie (Small)         3                          0
# Strawberry Banana Smoothie (Medium)        4                          0
# Strawberry Banana Smoothie (Large)         5                          0
#
#                                      Vitamin C (% Daily Value)  \
# Item
# Iced Tea (Small)                                             0
# Iced Tea (Medium)                                            0
# Iced Tea (Large)                                             0
# Iced Tea (Child)                                             0
# Coffee (Small)                                               0
# ...                                                        ...
# Frappé Chocolate Chip (Medium)                               0
# Frappé Chocolate Chip (Large)                                0
# Strawberry Banana Smoothie (Small)                          30
# Strawberry Banana Smoothie (Medium)                         35
# Strawberry Banana Smoothie (Large)                          45
#
#                                      Calcium (% Daily Value)  \
# Item
# Iced Tea (Small)                                           0
# Iced Tea (Medium)                                          0
# Iced Tea (Large)                                           0
# Iced Tea (Child)                                           0
# Coffee (Small)                                             0
# ...                                                      ...
# Frappé Chocolate Chip (Medium)                            30
# Frappé Chocolate Chip (Large)                             35
# Strawberry Banana Smoothie (Small)                         8
# Strawberry Banana Smoothie (Medium)                        8
# Strawberry Banana Smoothie (Large)                        10
#
#                                      Iron (% Daily Value)
# Item
# Iced Tea (Small)                                        0
# Iced Tea (Medium)                                       0
# Iced Tea (Large)                                        0
# Iced Tea (Child)                                        0
# Coffee (Small)                                          0
# ...                                                   ...
# Frappé Chocolate Chip (Medium)                          4
# Frappé Chocolate Chip (Large)                           6
# Strawberry Banana Smoothie (Small)                      2
# Strawberry Banana Smoothie (Medium)                     4
# Strawberry Banana Smoothie (Large)                      4
#
# [85 rows x 16 columns]

# %% [markdown]
# **Combinining two columns into one**:

# %% [markdown]
# SBUX beverages combined with prep details

# %%
#Adding column "Beverage Prep" to index column "Beverage"
sbux["Beverage Info"]= sbux.index.astype(str) + " - " + sbux["Beverage_prep"] + "-" +"SBUX"
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for new column
sbux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Brewed Coffee to Vanilla Bean (Without Whipped Cream)
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Beverage_category          85 non-null     object
#  1   Beverage_prep              85 non-null     object
#  2   Calories                   85 non-null     int64
#  3    Total Fat (g)             85 non-null     float64
#  4   Trans Fat (g)              85 non-null     float64
#  5   Saturated Fat (g)          85 non-null     float64
#  6    Sodium (mg)               85 non-null     int64
#  7    Total Carbohydrates (g)   85 non-null     int64
#  8   Cholesterol (mg)           85 non-null     int64
#  9    Dietary Fibre (g)         85 non-null     int64
#  10   Sugars (g)                85 non-null     int64
#  11   Protein (g)               85 non-null     int64
#  12  Vitamin A (% DV)           85 non-null     int64
#  13  Vitamin C (% DV)           85 non-null     int64
#  14   Calcium (% DV)            85 non-null     int64
#  15  Iron (% DV)                85 non-null     int64
#  16  Beverage Info              85 non-null     object
# dtypes: float64(3), int64(11), object(3)
# memory usage: 14.0+ KB

# %% [markdown]
# MCD items combined with serving sizes

# %%
#Adding column "Serving Size" to index column "Item"
mcd["Beverage Info"]=mcd.index.astype(str) + " - " + mcd["Serving Size"] + "-" +"MCD"
# displaying a summary of the dataframe that includes: column names, data types, non-null value counts
# check for new column
mcd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 85 entries, Iced Tea (Small) to Strawberry Banana Smoothie (Large)
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Category                   85 non-null     object
#  1   Serving Size               85 non-null     object
#  2   Calories                   85 non-null     int64
#  3   Total Fat                  85 non-null     float64
#  4   Saturated Fat              85 non-null     float64
#  5   Trans Fat                  85 non-null     float64
#  6   Cholesterol                85 non-null     int64
#  7   Sodium                     85 non-null     int64
#  8   Carbohydrates              85 non-null     int64
#  9   Dietary Fiber              85 non-null     int64
#  10  Sugars                     85 non-null     int64
#  11  Protein                    85 non-null     int64
#  12  Vitamin A (% Daily Value)  85 non-null     int64
#  13  Vitamin C (% Daily Value)  85 non-null     int64
#  14  Calcium (% Daily Value)    85 non-null     int64
#  15  Iron (% Daily Value)       85 non-null     int64
#  16  Beverage Info              85 non-null     object
# dtypes: float64(3), int64(11), object(3)
# memory usage: 12.0+ KB

# %% [markdown]
# Reviewing column names ahead of merge

# %%
print(sbux.columns)
# Out:
# Index(['Beverage_category', 'Beverage_prep', 'Calories', ' Total Fat (g)',
#        'Trans Fat (g) ', 'Saturated Fat (g)', ' Sodium (mg)',
#        ' Total Carbohydrates (g) ', 'Cholesterol (mg)', ' Dietary Fibre (g)',
#        ' Sugars (g)', ' Protein (g) ', 'Vitamin A (% DV) ', 'Vitamin C (% DV)',
#        ' Calcium (% DV) ', 'Iron (% DV) ', 'Beverage Info'],
#       dtype='object')

# %%
print(mcd.columns)
# Out:
# Index(['Category', 'Serving Size', 'Calories', 'Total Fat', 'Saturated Fat',
#        'Trans Fat', 'Cholesterol', 'Sodium', 'Carbohydrates', 'Dietary Fiber',
#        'Sugars', 'Protein', 'Vitamin A (% Daily Value)',
#        'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)',
#        'Iron (% Daily Value)', 'Beverage Info'],
#       dtype='object')

# %%
sbux
# Out:
#                                                       Beverage_category  \
# Beverage
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Brewed Coffee                                                    Coffee
# Caffè Latte                                     Classic Espresso Drinks
# ...                                                                 ...
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Java Chip                             Frappuccino® Light Blended Coffee
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
# Vanilla Bean (Without Whipped Cream)         Frappuccino® Blended Crème
#
#                                                 Beverage_prep  Calories  \
# Beverage
# Brewed Coffee                                           Short         3
# Brewed Coffee                                            Tall         4
# Brewed Coffee                                          Grande         5
# Brewed Coffee                                           Venti         5
# Caffè Latte                                 Short Nonfat Milk        70
# ...                                                       ...       ...
# Java Chip                               Tall Nonfat Milk Frap       150
# Java Chip                             Grande Nonfat Milk Frap       220
# Java Chip                              Venti Nonfat Milk Frap       290
# Vanilla Bean (Without Whipped Cream)    Tall Nonfat Milk Frap       170
# Vanilla Bean (Without Whipped Cream)  Grande Nonfat Milk Frap       240
#
#                                        Total Fat (g)  Trans Fat (g)   \
# Beverage
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Brewed Coffee                                   0.10            0.00
# Caffè Latte                                     0.10            0.10
# ...                                              ...             ...
# Java Chip                                       3.00            2.00
# Java Chip                                       4.00            3.00
# Java Chip                                       5.00            4.00
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
# Vanilla Bean (Without Whipped Cream)            0.10            0.10
#
#                                       Saturated Fat (g)   Sodium (mg)  \
# Beverage
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Brewed Coffee                                      0.00             0
# Caffè Latte                                        0.00             5
# ...                                                 ...           ...
# Java Chip                                          0.00             0
# Java Chip                                          0.00             0
# Java Chip                                          0.00             5
# Vanilla Bean (Without Whipped Cream)               0.00             0
# Vanilla Bean (Without Whipped Cream)               0.00             5
#
#                                        Total Carbohydrates (g)   \
# Beverage
# Brewed Coffee                                                 5
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Brewed Coffee                                                10
# Caffè Latte                                                  75
# ...                                                         ...
# Java Chip                                                   170
# Java Chip                                                   240
# Java Chip                                                   320
# Vanilla Bean (Without Whipped Cream)                        160
# Vanilla Bean (Without Whipped Cream)                        230
#
#                                       Cholesterol (mg)   Dietary Fibre (g)  \
# Beverage
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Brewed Coffee                                        0                   0
# Caffè Latte                                         10                   0
# ...                                                ...                 ...
# Java Chip                                           30                   1
# Java Chip                                           43                   2
# Java Chip                                           58                   2
# Vanilla Bean (Without Whipped Cream)                39                   0
# Vanilla Bean (Without Whipped Cream)                56                   0
#
#                                        Sugars (g)   Protein (g)   \
# Beverage
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              0
# Brewed Coffee                                   0              1
# Brewed Coffee                                   0              1
# Caffè Latte                                     9              6
# ...                                           ...            ...
# Java Chip                                      27              4
# Java Chip                                      39              5
# Java Chip                                      52              7
# Vanilla Bean (Without Whipped Cream)           38              4
# Vanilla Bean (Without Whipped Cream)           55              5
#
#                                       Vitamin A (% DV)   Vitamin C (% DV)  \
# Beverage
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Brewed Coffee                                         0                 0
# Caffè Latte                                          10                 0
# ...                                                 ...               ...
# Java Chip                                             4                 0
# Java Chip                                             6                 0
# Java Chip                                             8                 0
# Vanilla Bean (Without Whipped Cream)                  6                 0
# Vanilla Bean (Without Whipped Cream)                  8                 0
#
#                                        Calcium (% DV)   Iron (% DV)   \
# Beverage
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        0             0
# Brewed Coffee                                        2             0
# Caffè Latte                                         20             0
# ...                                                ...           ...
# Java Chip                                           10            20
# Java Chip                                           10            25
# Java Chip                                           15            35
# Vanilla Bean (Without Whipped Cream)                10             0
# Vanilla Bean (Without Whipped Cream)                15             0
#
#                                                                           Beverage Info
# Beverage
# Brewed Coffee                                                Brewed Coffee - Short-SBUX
# Brewed Coffee                                                 Brewed Coffee - Tall-SBUX
# Brewed Coffee                                               Brewed Coffee - Grande-SBUX
# Brewed Coffee                                                Brewed Coffee - Venti-SBUX
# Caffè Latte                                        Caffè Latte - Short Nonfat Milk-SBUX
# ...                                                                                 ...
# Java Chip                                        Java Chip - Tall Nonfat Milk Frap-SBUX
# Java Chip                                      Java Chip - Grande Nonfat Milk Frap-SBUX
# Java Chip                                       Java Chip - Venti Nonfat Milk Frap-SBUX
# Vanilla Bean (Without Whipped Cream)  Vanilla Bean (Without Whipped Cream) - Tall No...
# Vanilla Bean (Without Whipped Cream)  Vanilla Bean (Without Whipped Cream) - Grande ...
#
# [85 rows x 17 columns]

# %% [markdown]
# **Renaming column names to optimize consistency between two data sets ahead of merge**:

# %%
# renaming columns for consistency
sbux = sbux.rename(columns={' Total Fat (g)':'Total Fat (g)', 'Trans Fat (g) ':'Trans Fat (g)',' Sodium (mg)':'Sodium (mg)',' Total Carbohydrates (g) ':'Total Carbohydrates (g)',' Dietary Fibre (g)':'Dietary Fiber (g)',' Sugars (g)':'Sugars (g)',' Protein (g) ':'Protein (g)','Vitamin A (% DV) ':'Vitamin A (% DV)',' Calcium (% DV) ':'Calcium (% DV)','Iron (% DV) ':'Iron (% DV)'})

# %%
# renaming columns for consistency
mcd = mcd.rename(columns={'Total Fat':'Total Fat (g)', 'Trans Fat':'Trans Fat (g)','Saturated Fat':'Saturated Fat (g)', 'Cholesterol':'Cholesterol (mg)','Sodium':'Sodium (mg)','Carbohydrates':'Total Carbohydrates (g)','Dietary Fiber':'Dietary Fiber (g)','Sugars':'Sugars (g)','Protein':'Protein (g)','Vitamin A (% Daily Value)':'Vitamin A (% DV)','Vitamin C (% Daily Value)':'Vitamin C (% DV)','Calcium (% Daily Value)':'Calcium (% DV)','Iron (% Daily Value)':'Iron (% DV)'})

# %% [markdown]
# Checking updated column names.

# %%
print(sbux.columns)
print(mcd.columns)
# Out:
# Index(['Beverage_category', 'Beverage_prep', 'Calories', 'Total Fat (g)',
#        'Trans Fat (g)', 'Saturated Fat (g)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Cholesterol (mg)', 'Dietary Fiber (g)',
#        'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)',
#        'Calcium (% DV)', 'Iron (% DV)', 'Beverage Info'],
#       dtype='object')
# Index(['Category', 'Serving Size', 'Calories', 'Total Fat (g)',
#        'Saturated Fat (g)', 'Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Dietary Fiber (g)', 'Sugars (g)',
#        'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)', 'Calcium (% DV)',
#        'Iron (% DV)', 'Beverage Info'],
#       dtype='object')

# %% [markdown]
# #### Changing Index Columns

# %%
sbux = sbux.set_index("Beverage Info")
mcd = mcd.set_index("Beverage Info")

# %%
print(sbux.columns)
print(mcd.columns)
# Out:
# Index(['Beverage_category', 'Beverage_prep', 'Calories', 'Total Fat (g)',
#        'Trans Fat (g)', 'Saturated Fat (g)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Cholesterol (mg)', 'Dietary Fiber (g)',
#        'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)',
#        'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')
# Index(['Category', 'Serving Size', 'Calories', 'Total Fat (g)',
#        'Saturated Fat (g)', 'Trans Fat (g)', 'Cholesterol (mg)', 'Sodium (mg)',
#        'Total Carbohydrates (g)', 'Dietary Fiber (g)', 'Sugars (g)',
#        'Protein (g)', 'Vitamin A (% DV)', 'Vitamin C (% DV)', 'Calcium (% DV)',
#        'Iron (% DV)'],
#       dtype='object')

# %% [markdown]
# **Deleting uncessary columns**

# %%
# Dropping surplus columns
sbux_new = sbux.drop(columns=["Beverage_prep","Beverage_category"])

# %%
# Dropping surplus columns
mcd_new = mcd.drop(columns=["Serving Size","Category"])

# %% [markdown]
# Observing updates

# %%
print(sbux_new.columns)
print(mcd_new.columns)
# Out:
# Index(['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Saturated Fat (g)',
#        'Sodium (mg)', 'Total Carbohydrates (g)', 'Cholesterol (mg)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')
# Index(['Calories', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)', 'Total Carbohydrates (g)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')

# %% [markdown]
# **Creating backup files**

# %%
#storing original versions in case restore needed
orignal_sbux_columns = list(sbux_new.columns)
orignal_mcd_columns = list(mcd_new.columns)

orignal_sbux = sbux
orignal_mcd = mcd

# %% [markdown]
# #### Normalizaton: Creating a uniform scale
#
# Changing SBUX column order to match MCD column order (preferred)

# %%
#changing order of SBUX columns
sbux = sbux_new[['Calories', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
       'Cholesterol (mg)', 'Sodium (mg)', 'Total Carbohydrates (g)',
       'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
       'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)']]
#checking updates for comparison
print(sbux_new.columns)
print(mcd_new.columns)
# Out:
# Index(['Calories', 'Total Fat (g)', 'Trans Fat (g)', 'Saturated Fat (g)',
#        'Sodium (mg)', 'Total Carbohydrates (g)', 'Cholesterol (mg)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')
# Index(['Calories', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)', 'Total Carbohydrates (g)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')

# %%
mcd = mcd_new

# %%
print(sbux.index)
# Out:
# Index(['Brewed Coffee - Short-SBUX', 'Brewed Coffee - Tall-SBUX',
#        'Brewed Coffee - Grande-SBUX', 'Brewed Coffee - Venti-SBUX',
#        'Caffè Latte - Short Nonfat Milk-SBUX', 'Caffè Latte - 2% Milk-SBUX',
#        'Caffè Latte - Tall Nonfat Milk-SBUX', 'Caffè Latte - 2% Milk-SBUX',
#        'Caffè Latte - Grande Nonfat Milk-SBUX', 'Caffè Latte - 2% Milk-SBUX',
#        'Caffè Latte - Venti Nonfat Milk-SBUX', 'Caffè Latte - 2% Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - Short Nonfat Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - 2% Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - Tall Nonfat Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - 2% Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - Grande Nonfat Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - 2% Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - Venti Nonfat Milk-SBUX',
#        'Caffè Mocha (Without Whipped Cream) - 2% Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - Short Nonfat Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - 2% Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - Tall Nonfat Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - 2% Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - Grande Nonfat Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - 2% Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - Venti Nonfat Milk-SBUX',
#        'Vanilla Latte (Or Other Flavoured Latte) - 2% Milk-SBUX',
#        'Skinny Latte (Any Flavour) - Short Nonfat Milk-SBUX',
#        'Skinny Latte (Any Flavour) - Tall Nonfat Milk-SBUX',
#        'Skinny Latte (Any Flavour) - Grande Nonfat Milk-SBUX',
#        'Skinny Latte (Any Flavour) - Venti Nonfat Milk-SBUX',
#        'Caramel Macchiato - Short Nonfat Milk-SBUX',
#        'Caramel Macchiato - 2% Milk-SBUX',
#        'Caramel Macchiato - Tall Nonfat Milk-SBUX',
#        'Caramel Macchiato - 2% Milk-SBUX',
#        'Caramel Macchiato - Grande Nonfat Milk-SBUX',
#        'Caramel Macchiato - 2% Milk-SBUX',
#        'Caramel Macchiato - Venti Nonfat Milk-SBUX',
#        'Caramel Macchiato - 2% Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - Short Nonfat Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - 2% Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - Tall Nonfat Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - 2% Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - Grande Nonfat Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - 2% Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - Venti Nonfat Milk-SBUX',
#        'Hot Chocolate (Without Whipped Cream) - 2% Milk-SBUX',
#        'Iced Brewed Coffee (With Classic Syrup) - Tall-SBUX',
#        'Iced Brewed Coffee (With Classic Syrup) - Grande-SBUX',
#        'Iced Brewed Coffee (With Classic Syrup) - Venti-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - Tall Nonfat Milk-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - 2% Milk-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - Grande Nonfat Milk-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - 2% Milk-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - Venti Nonfat Milk-SBUX',
#        'Iced Brewed Coffee (With Milk & Classic Syrup) - 2% Milk-SBUX',
#        'Strawberry Banana Smoothie - Grande Nonfat Milk-SBUX',
#        'Strawberry Banana Smoothie - 2% Milk-SBUX',
#        'Coffee - Tall Nonfat Milk Frap-SBUX',
#        'Coffee - Grande Nonfat Milk Frap-SBUX',
#        'Coffee - Venti Nonfat Milk Frap-SBUX',
#        'Mocha (Without Whipped Cream) - Tall Nonfat Milk Frap-SBUX',
#        'Mocha (Without Whipped Cream) - Grande Nonfat Milk Frap-SBUX',
#        'Mocha (Without Whipped Cream) - Venti Nonfat Milk Frap-SBUX',
#        'Caramel (Without Whipped Cream) - Tall Nonfat Milk Frap-SBUX',
#        'Caramel (Without Whipped Cream) - Grande Nonfat Milk Frap-SBUX',
#        'Caramel (Without Whipped Cream) - Venti Nonfat Milk Frap-SBUX',
#        'Java Chip (Without Whipped Cream) - Tall Nonfat Milk Frap-SBUX',
#        'Java Chip (Without Whipped Cream) - Grande Nonfat Milk Frap-SBUX',
#        'Java Chip (Without Whipped Cream) - Venti Nonfat Milk Frap-SBUX',
#        'Coffee - Tall Nonfat Milk Frap-SBUX',
#        'Coffee - Grande Nonfat Milk Frap-SBUX',
#        'Coffee - Venti Nonfat Milk Frap-SBUX',
#        'Mocha - Tall Nonfat Milk Frap-SBUX',
#        'Mocha - Grande Nonfat Milk Frap-SBUX',
#        'Mocha - Venti Nonfat Milk Frap-SBUX',
#        'Caramel - Tall Nonfat Milk Frap-SBUX',
#        'Caramel - Grande Nonfat Milk Frap-SBUX',
#        'Caramel - Venti Nonfat Milk Frap-SBUX',
#        'Java Chip - Tall Nonfat Milk Frap-SBUX',
#        'Java Chip - Grande Nonfat Milk Frap-SBUX',
#        'Java Chip - Venti Nonfat Milk Frap-SBUX',
#        'Vanilla Bean (Without Whipped Cream) - Tall Nonfat Milk Frap-SBUX',
#        'Vanilla Bean (Without Whipped Cream) - Grande Nonfat Milk Frap-SBUX'],
#       dtype='object', name='Beverage Info')

# %%
print(mcd.index)
# Out:
# Index(['Iced Tea (Small) - 16 fl oz cup-MCD',
#        'Iced Tea (Medium) - 21 fl oz cup-MCD',
#        'Iced Tea (Large) - 30 fl oz cup-MCD',
#        'Iced Tea (Child) - 12 fl oz cup-MCD',
#        'Coffee (Small) - 12 fl oz cup-MCD',
#        'Coffee (Medium) - 16 fl oz cup-MCD',
#        'Coffee (Large) - 16 fl oz cup-MCD', 'Latte (Small) - 12 fl oz cup-MCD',
#        'Latte (Medium) - 16 fl oz cup-MCD', 'Latte (Large) - 20 fl oz cup-MCD',
#        'Caramel Latte (Small) - 12 fl oz cup-MCD',
#        'Caramel Latte (Medium) - 16 fl oz cup-MCD',
#        'Caramel Latte (Large) - 20 fl oz cup-MCD',
#        'French Vanilla Latte (Small) - 12 fl oz cup-MCD',
#        'French Vanilla Latte (Medium) - 16 fl oz cup-MCD',
#        'French Vanilla Latte (Large) - 20 fl oz cup-MCD',
#        'Latte with Sugar Free French Vanilla Syrup (Small) - 12 fl oz cup-MCD',
#        'Latte with Sugar Free French Vanilla Syrup (Medium) - 16 fl oz cup-MCD',
#        'Latte with Sugar Free French Vanilla Syrup (Large) - 20 fl oz cup-MCD',
#        'Nonfat Latte (Small) - 12 fl oz cup-MCD',
#        'Nonfat Latte (Medium) - 16 fl oz cup-MCD',
#        'Nonfat Latte (Large) - 20 fl oz cup-MCD',
#        'Nonfat Caramel Latte (Small) - 12 fl oz cup-MCD',
#        'Nonfat Caramel Latte (Medium) - 16 fl oz cup-MCD',
#        'Nonfat Caramel Latte (Large) - 20 fl oz cup-MCD',
#        'Nonfat French Vanilla Latte (Small) - 12 fl oz cup-MCD',
#        'Nonfat French Vanilla Latte (Medium) - 16 fl oz cup-MCD',
#        'Nonfat French Vanilla Latte (Large) - 20 fl oz cup-MCD',
#        'Nonfat Latte with Sugar Free French Vanilla Syrup (Small) - 12 fl oz cup-MCD',
#        'Nonfat Latte with Sugar Free French Vanilla Syrup (Medium) - 16 fl oz cup-MCD',
#        'Nonfat Latte with Sugar Free French Vanilla Syrup (Large) - 20 fl oz cup-MCD',
#        'Mocha (Small) - 12 fl oz cup-MCD', 'Mocha (Medium) - 16 fl oz cup-MCD',
#        'Mocha (Large) - 20 fl oz cup-MCD',
#        'Mocha with Nonfat Milk (Small) - 12 fl oz cup-MCD',
#        'Mocha with Nonfat Milk (Medium) - 16 fl oz cup-MCD',
#        'Mocha with Nonfat Milk (Large) - 20 fl oz cup-MCD',
#        'Caramel Mocha (Small) - 12 fl oz cup-MCD',
#        'Caramel Mocha (Medium) - 16 fl oz cup-MCD',
#        'Caramel Mocha (Large) - 20 fl oz cup-MCD',
#        'Nonfat Caramel Mocha (Small) - 12 fl oz cup-MCD',
#        'Nonfat Caramel Mocha (Medium) - 16 fl oz cup-MCD',
#        'Nonfat Caramel Mocha (Large) - 20 fl oz cup-MCD',
#        'Hot Chocolate (Small) - 12 fl oz cup-MCD',
#        'Hot Chocolate (Medium) - 16 fl oz cup-MCD',
#        'Hot Chocolate (Large) - 20 fl oz cup-MCD',
#        'Hot Chocolate with Nonfat Milk (Small) - 12 fl oz cup-MCD',
#        'Hot Chocolate with Nonfat Milk (Medium) - 16 fl oz cup-MCD',
#        'Hot Chocolate with Nonfat Milk (Large) - 20 fl oz cup-MCD',
#        'Regular Iced Coffee (Small) - 16 fl oz cup-MCD',
#        'Regular Iced Coffee (Medium) - 22 fl oz cup-MCD',
#        'Regular Iced Coffee (Large) - 32 fl oz cup-MCD',
#        'Caramel Iced Coffee (Small) - 16 fl oz cup-MCD',
#        'Caramel Iced Coffee (Medium) - 22 fl oz cup-MCD',
#        'Caramel Iced Coffee (Large) - 32 fl oz cup-MCD',
#        'French Vanilla Iced Coffee (Small) - 16 fl oz cup-MCD',
#        'French Vanilla Iced Coffee (Medium) - 22 fl oz cup-MCD',
#        'French Vanilla Iced Coffee (Large) - 32 fl oz cup-MCD',
#        'Iced Coffee with Sugar Free French Vanilla Syrup (Small) - 16 fl oz cup-MCD',
#        'Iced Coffee with Sugar Free French Vanilla Syrup (Medium) - 22 fl oz cup-MCD',
#        'Iced Coffee with Sugar Free French Vanilla Syrup (Large) - 32 fl oz cup-MCD',
#        'Iced Mocha (Small) - 12 fl oz cup-MCD',
#        'Iced Mocha (Medium) - 16 fl oz cup-MCD',
#        'Iced Mocha (Large) - 22 fl oz cup-MCD',
#        'Iced Mocha with Nonfat Milk (Small) - 12 fl oz cup-MCD',
#        'Iced Mocha with Nonfat Milk (Medium) - 16 fl oz cup-MCD',
#        'Iced Mocha with Nonfat Milk (Large) - 22 fl oz cup-MCD',
#        'Iced Caramel Mocha (Small) - 12 fl oz cup-MCD',
#        'Iced Caramel Mocha (Medium) - 16 fl oz cup-MCD',
#        'Iced Caramel Mocha (Large) - 22 fl oz cup-MCD',
#        'Iced Nonfat Caramel Mocha (Small) - 12 fl oz cup-MCD',
#        'Iced Nonfat Caramel Mocha (Medium) - 16 fl oz cup-MCD',
#        'Iced Nonfat Caramel Mocha (Large) - 22 fl oz cup-MCD',
#        'Frappé Mocha (Small) - 12 fl oz cup Frap-MCD',
#        'Frappé Mocha (Medium) - 16 fl oz cup Frap-MCD',
#        'Frappé Mocha (Large) - 22 fl oz cup Frap-MCD',
#        'Frappé Caramel (Small) - 12 fl oz cup Frap-MCD',
#        'Frappé Caramel (Medium) - 16 fl oz cup Frap-MCD',
#        'Frappé Caramel (Large) - 22 fl oz cup Frap-MCD',
#        'Frappé Chocolate Chip (Small) - 12 fl oz cup Frap-MCD',
#        'Frappé Chocolate Chip (Medium) - 16 fl oz cup Frap-MCD',
#        'Frappé Chocolate Chip (Large) - 22 fl oz cup Frap-MCD',
#        'Strawberry Banana Smoothie (Small) - 12 fl oz cup-MCD',
#        'Strawberry Banana Smoothie (Medium) - 16 fl oz cup-MCD',
#        'Strawberry Banana Smoothie (Large) - 22 fl oz cup-MCD'],
#       dtype='object', name='Beverage Info')

# %% [markdown]
# ### Merging/Joining: Combining two dataframes into one

# %% [markdown]
# **Pandas Merge method**

# %% [markdown]
#  Merging two dataframes using outer join would follow the following code:
# *combined_a = pd.merge(sbux,mcd, how='outer', left_index=True, right_index=True)*
#
# Using the above method would ensure *all* rows are included in new dataframe. However, it works better for cominbining by matching keys or indices.
#
# Since the two dataframes have been cleaned and prepared to contain similar columns, the concatenation method is a more effective approach to allow for comparison between the two restaurants.

# %% [markdown]
# **Concatenating method**

# %% [markdown]
# This method merges *all* rows from two dataframes that share the same structure (column names) aligning them along the 0 axis (i.e. index/"Beverage Info")

# %%
#Concatenating two dataframes
combined = pd.concat([sbux, mcd], axis=0)

# %% [markdown]
# Checking concatenated dataframes

# %%
combined.shape
# Out:
# (170, 14)

# %%
combined.head(5)
# Out:
#                                       Calories  Total Fat (g)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                   3           0.10
# Brewed Coffee - Tall-SBUX                    4           0.10
# Brewed Coffee - Grande-SBUX                  5           0.10
# Brewed Coffee - Venti-SBUX                   5           0.10
# Caffè Latte - Short Nonfat Milk-SBUX        70           0.10
#
#                                       Saturated Fat (g)  Trans Fat (g)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                         0.00           0.00
# Brewed Coffee - Tall-SBUX                          0.00           0.00
# Brewed Coffee - Grande-SBUX                        0.00           0.00
# Brewed Coffee - Venti-SBUX                         0.00           0.00
# Caffè Latte - Short Nonfat Milk-SBUX               0.00           0.10
#
#                                       Cholesterol (mg)  Sodium (mg)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                           0            0
# Brewed Coffee - Tall-SBUX                            0            0
# Brewed Coffee - Grande-SBUX                          0            0
# Brewed Coffee - Venti-SBUX                           0            0
# Caffè Latte - Short Nonfat Milk-SBUX                10            5
#
#                                       Total Carbohydrates (g)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                                  5
# Brewed Coffee - Tall-SBUX                                  10
# Brewed Coffee - Grande-SBUX                                10
# Brewed Coffee - Venti-SBUX                                 10
# Caffè Latte - Short Nonfat Milk-SBUX                       75
#
#                                       Dietary Fiber (g)  Sugars (g)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                            0           0
# Brewed Coffee - Tall-SBUX                             0           0
# Brewed Coffee - Grande-SBUX                           0           0
# Brewed Coffee - Venti-SBUX                            0           0
# Caffè Latte - Short Nonfat Milk-SBUX                  0           9
#
#                                       Protein (g)  Vitamin A (% DV)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                      0                 0
# Brewed Coffee - Tall-SBUX                       0                 0
# Brewed Coffee - Grande-SBUX                     1                 0
# Brewed Coffee - Venti-SBUX                      1                 0
# Caffè Latte - Short Nonfat Milk-SBUX            6                10
#
#                                       Vitamin C (% DV)  Calcium (% DV)  \
# Beverage Info
# Brewed Coffee - Short-SBUX                           0               0
# Brewed Coffee - Tall-SBUX                            0               0
# Brewed Coffee - Grande-SBUX                          0               0
# Brewed Coffee - Venti-SBUX                           0               2
# Caffè Latte - Short Nonfat Milk-SBUX                 0              20
#
#                                       Iron (% DV)
# Beverage Info
# Brewed Coffee - Short-SBUX                      0
# Brewed Coffee - Tall-SBUX                       0
# Brewed Coffee - Grande-SBUX                     0
# Brewed Coffee - Venti-SBUX                      0
# Caffè Latte - Short Nonfat Milk-SBUX            0

# %%
combined.tail(5)
# Out:
#                                                     Calories  Total Fat (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...       630          26.00
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...       760          31.00
# Strawberry Banana Smoothie (Small) - 12 fl oz c...       210           0.50
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...       250           1.00
# Strawberry Banana Smoothie (Large) - 22 fl oz c...       330           1.00
#
#                                                     Saturated Fat (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...              17.00
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...              20.00
# Strawberry Banana Smoothie (Small) - 12 fl oz c...               0.00
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...               0.00
# Strawberry Banana Smoothie (Large) - 22 fl oz c...               0.50
#
#                                                     Trans Fat (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...           1.00
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...           1.50
# Strawberry Banana Smoothie (Small) - 12 fl oz c...           0.00
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...           0.00
# Strawberry Banana Smoothie (Large) - 22 fl oz c...           0.00
#
#                                                     Cholesterol (mg)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...                80
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...                95
# Strawberry Banana Smoothie (Small) - 12 fl oz c...                 5
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...                 5
# Strawberry Banana Smoothie (Large) - 22 fl oz c...                 5
#
#                                                     Sodium (mg)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...          160
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...          200
# Strawberry Banana Smoothie (Small) - 12 fl oz c...           50
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...           60
# Strawberry Banana Smoothie (Large) - 22 fl oz c...           80
#
#                                                     Total Carbohydrates (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...                       91
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...                      111
# Strawberry Banana Smoothie (Small) - 12 fl oz c...                       47
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...                       58
# Strawberry Banana Smoothie (Large) - 22 fl oz c...                       74
#
#                                                     Dietary Fiber (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...                  1
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...                  1
# Strawberry Banana Smoothie (Small) - 12 fl oz c...                  3
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...                  3
# Strawberry Banana Smoothie (Large) - 22 fl oz c...                  4
#
#                                                     Sugars (g)  Protein (g)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...          81            9
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...          99           12
# Strawberry Banana Smoothie (Small) - 12 fl oz c...          44            3
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...          54            4
# Strawberry Banana Smoothie (Large) - 22 fl oz c...          70            5
#
#                                                     Vitamin A (% DV)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...                15
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...                20
# Strawberry Banana Smoothie (Small) - 12 fl oz c...                 0
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...                 0
# Strawberry Banana Smoothie (Large) - 22 fl oz c...                 0
#
#                                                     Vitamin C (% DV)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...                 0
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...                 0
# Strawberry Banana Smoothie (Small) - 12 fl oz c...                30
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...                35
# Strawberry Banana Smoothie (Large) - 22 fl oz c...                45
#
#                                                     Calcium (% DV)  \
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...              30
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...              35
# Strawberry Banana Smoothie (Small) - 12 fl oz c...               8
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...               8
# Strawberry Banana Smoothie (Large) - 22 fl oz c...              10
#
#                                                     Iron (% DV)
# Beverage Info
# Frappé Chocolate Chip (Medium) - 16 fl oz cup F...            4
# Frappé Chocolate Chip (Large) - 22 fl oz cup Fr...            6
# Strawberry Banana Smoothie (Small) - 12 fl oz c...            2
# Strawberry Banana Smoothie (Medium) - 16 fl oz ...            4
# Strawberry Banana Smoothie (Large) - 22 fl oz c...            4

# %%
#checking updates for comparison
print(combined.columns)
# Out:
# Index(['Calories', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)', 'Total Carbohydrates (g)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)'],
#       dtype='object')

# %% [markdown]
# Dropping "Short" items from SBUX for uniformity given no size comparison to MCD items.

# %%
combined = combined[~combined.index.str.contains("Short", case = False)]
combined.shape
# Out:
# (163, 14)

# %% [markdown]
# ### Feature Engineering: Creating New Columns

# %% [markdown]
# **Calculating Percentages & Converting Ratios into New Columns**

# %%
# creatng new columns for ratios of X-to-calories
combined['Chol_to_C'] = (combined['Cholesterol (mg)'] / combined['Calories'])
combined['Carb_to_C'] = (combined['Total Carbohydrates (g)'] / combined['Calories'])
combined['F_to_C'] = (combined['Dietary Fiber (g)'] / combined['Calories'])
combined['S_to_C'] = (combined['Sugars (g)'] / combined['Calories'])
combined['P_to_C'] = (combined['Protein (g)'] / combined['Calories'])
combined['A_to_C'] = (combined['Vitamin A (% DV)'] / combined['Calories'])
combined['C_to_C'] = (combined['Vitamin C (% DV)'] / combined['Calories'])
combined['Ca_to_C'] = (combined['Calcium (% DV)'] / combined['Calories'])
combined['Fe_to_C'] = (combined['Iron (% DV)'] / combined['Calories'])


# Data Preparation: converting new columns to percentages.  
combined['Chol_to_C'] = combined['Chol_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['Carb_to_C'] = combined['Carb_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['F_to_C'] = combined['F_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['S_to_C'] = combined['S_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['P_to_C'] = combined['P_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['A_to_C'] = combined['A_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['C_to_C'] = combined['C_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['Ca_to_C'] = combined['Ca_to_C'].apply(lambda x: f"{x * 100:.2f}%")
combined['Fe_to_C'] = combined['Fe_to_C'].apply(lambda x: f"{x * 100:.2f}%")

# displaying updated dataframe
combined.head(5)
# Out:
#                                      Calories  Total Fat (g)  \
# Beverage Info
# Brewed Coffee - Tall-SBUX                   4           0.10
# Brewed Coffee - Grande-SBUX                 5           0.10
# Brewed Coffee - Venti-SBUX                  5           0.10
# Caffè Latte - 2% Milk-SBUX                100           3.50
# Caffè Latte - Tall Nonfat Milk-SBUX       100           0.20
#
#                                      Saturated Fat (g)  Trans Fat (g)  \
# Beverage Info
# Brewed Coffee - Tall-SBUX                         0.00           0.00
# Brewed Coffee - Grande-SBUX                       0.00           0.00
# Brewed Coffee - Venti-SBUX                        0.00           0.00
# Caffè Latte - 2% Milk-SBUX                        0.10           2.00
# Caffè Latte - Tall Nonfat Milk-SBUX               0.00           0.20
#
#                                      Cholesterol (mg)  Sodium (mg)  \
# Beverage Info
# Brewed Coffee - Tall-SBUX                           0            0
# Brewed Coffee - Grande-SBUX                         0            0
# Brewed Coffee - Venti-SBUX                          0            0
# Caffè Latte - 2% Milk-SBUX                         10           15
# Caffè Latte - Tall Nonfat Milk-SBUX                15            5
#
#                                      Total Carbohydrates (g)  \
# Beverage Info
# Brewed Coffee - Tall-SBUX                                 10
# Brewed Coffee - Grande-SBUX                               10
# Brewed Coffee - Venti-SBUX                                10
# Caffè Latte - 2% Milk-SBUX                                85
# Caffè Latte - Tall Nonfat Milk-SBUX                      120
#
#                                      Dietary Fiber (g)  Sugars (g)  \
# Beverage Info
# Brewed Coffee - Tall-SBUX                            0           0
# Brewed Coffee - Grande-SBUX                          0           0
# Brewed Coffee - Venti-SBUX                           0           0
# Caffè Latte - 2% Milk-SBUX                           0           9
# Caffè Latte - Tall Nonfat Milk-SBUX                  0          14
#
#                                      Protein (g)  ...  Iron (% DV)  Chol_to_C  \
# Beverage Info                                     ...
# Brewed Coffee - Tall-SBUX                      0  ...            0      0.00%
# Brewed Coffee - Grande-SBUX                    1  ...            0      0.00%
# Brewed Coffee - Venti-SBUX                     1  ...            0      0.00%
# Caffè Latte - 2% Milk-SBUX                     6  ...            0     10.00%
# Caffè Latte - Tall Nonfat Milk-SBUX           10  ...            0     15.00%
#
#                                      Carb_to_C  F_to_C  S_to_C  P_to_C  \
# Beverage Info
# Brewed Coffee - Tall-SBUX              250.00%   0.00%   0.00%   0.00%
# Brewed Coffee - Grande-SBUX            200.00%   0.00%   0.00%  20.00%
# Brewed Coffee - Venti-SBUX             200.00%   0.00%   0.00%  20.00%
# Caffè Latte - 2% Milk-SBUX              85.00%   0.00%   9.00%   6.00%
# Caffè Latte - Tall Nonfat Milk-SBUX    120.00%   0.00%  14.00%  10.00%
#
#                                      A_to_C C_to_C Ca_to_C Fe_to_C
# Beverage Info
# Brewed Coffee - Tall-SBUX             0.00%  0.00%   0.00%   0.00%
# Brewed Coffee - Grande-SBUX           0.00%  0.00%   0.00%   0.00%
# Brewed Coffee - Venti-SBUX            0.00%  0.00%  40.00%   0.00%
# Caffè Latte - 2% Milk-SBUX           10.00%  0.00%  20.00%   0.00%
# Caffè Latte - Tall Nonfat Milk-SBUX  15.00%  0.00%  30.00%   0.00%
#
# [5 rows x 23 columns]

# %% [markdown]
# Checking newly created columns

# %%
#checking updates for comparison
print(combined.columns)
# Out:
# Index(['Calories', 'Total Fat (g)', 'Saturated Fat (g)', 'Trans Fat (g)',
#        'Cholesterol (mg)', 'Sodium (mg)', 'Total Carbohydrates (g)',
#        'Dietary Fiber (g)', 'Sugars (g)', 'Protein (g)', 'Vitamin A (% DV)',
#        'Vitamin C (% DV)', 'Calcium (% DV)', 'Iron (% DV)', 'Chol_to_C',
#        'Carb_to_C', 'F_to_C', 'S_to_C', 'P_to_C', 'A_to_C', 'C_to_C',
#        'Ca_to_C', 'Fe_to_C'],
#       dtype='object')

# %% [markdown]
# *Created a backup file for concatenated data*

# %%
combined_backup = combined

# %% [markdown]
# Optimizing consistency across restaurants.

# %%
# replacing phrases in indices to optimize consistency 
combined.index = combined.index.str.replace("(Small) - 12 fl oz cup", "- Tall", case=False)
combined.index = combined.index.str.replace("(Medium) - 16 fl oz cup", "- Grande", case=False)
combined.index = combined.index.str.replace("(Large) - 20 fl oz cup", "- Venti", case=False)

# %%
#reviewing index updates
combined.shape
# Out:
# (163, 23)

# %% [markdown]
# ### Exploratory Data Aanlysis

# %% [markdown]
# **Descriptive Statistics**:
#
# Providing summary statistics (mean, median, min, max) for numerical columns.

# %%
# improving readiblity and presentation by standardizing all values to 2 decimal places.
pd.set_option('display.float_format', '{:.2f}'.format)

# providing a statistical summarized overview  of the numeric columns (includes mean, median, min/max, std of the data).
# identifying outliers and understanding data distribution 
combined.describe()
# Out:
#        Calories  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# count    163.00         163.00             163.00         163.00
# mean     243.58           5.54               2.69           0.75
# std      140.43           6.55               4.29           1.32
# min        0.00           0.00               0.00           0.00
# 25%      150.00           0.25               0.00           0.00
# 50%      230.00           3.50               0.10           0.10
# 75%      320.00           9.00               4.50           1.00
# max      760.00          31.00              20.00           6.00
#
#        Cholesterol (mg)  Sodium (mg)  Total Carbohydrates (g)  \
# count            163.00       163.00                   163.00
# mean              32.09        78.62                    94.98
# std               21.25        85.25                    77.51
# min                0.00         0.00                     0.00
# 25%               17.00         5.00                    38.50
# 50%               30.00        35.00                    66.00
# 75%               43.00       150.00                   150.00
# max               95.00       280.00                   340.00
#
#        Dietary Fiber (g)  Sugars (g)  Protein (g)  Vitamin A (% DV)  \
# count             163.00      163.00       163.00            163.00
# mean                0.80       36.69         8.47             11.19
# std                 1.05       20.85         5.24              7.05
# min                 0.00        0.00         0.00              0.00
# 25%                 0.00       21.00         4.00              6.00
# 50%                 1.00       36.00         9.00             10.00
# 75%                 1.00       50.50        12.50             15.00
# max                 7.00       99.00        19.00             30.00
#
#        Vitamin C (% DV)  Calcium (% DV)  Iron (% DV)
# count            163.00          163.00       163.00
# mean               2.02           25.52         4.83
# std               12.05           16.41         8.01
# min                0.00            0.00         0.00
# 25%                0.00           10.00         0.00
# 50%                0.00           30.00         2.00
# 75%                0.00           40.00         6.00
# max              100.00           60.00        35.00

# %% [markdown]
# Arranging Index in Alphabetical Order

# %%
# changing index (Beverage Info) to ABC order
combined.sort_index(ascending=True, inplace=True)

# %%
#displaying changes
combined.head(5)
# Out:
#                              Calories  Total Fat (g)  Saturated Fat (g)  \
# Beverage Info
# Brewed Coffee - Grande-SBUX         5           0.10               0.00
# Brewed Coffee - Tall-SBUX           4           0.10               0.00
# Brewed Coffee - Venti-SBUX          5           0.10               0.00
# Caffè Latte - 2% Milk-SBUX        100           3.50               0.10
# Caffè Latte - 2% Milk-SBUX        150           6.00               0.20
#
#                              Trans Fat (g)  Cholesterol (mg)  Sodium (mg)  \
# Beverage Info
# Brewed Coffee - Grande-SBUX           0.00                 0            0
# Brewed Coffee - Tall-SBUX             0.00                 0            0
# Brewed Coffee - Venti-SBUX            0.00                 0            0
# Caffè Latte - 2% Milk-SBUX            2.00                10           15
# Caffè Latte - 2% Milk-SBUX            3.00                15           25
#
#                              Total Carbohydrates (g)  Dietary Fiber (g)  \
# Beverage Info
# Brewed Coffee - Grande-SBUX                       10                  0
# Brewed Coffee - Tall-SBUX                         10                  0
# Brewed Coffee - Venti-SBUX                        10                  0
# Caffè Latte - 2% Milk-SBUX                        85                  0
# Caffè Latte - 2% Milk-SBUX                       135                  0
#
#                              Sugars (g)  Protein (g)  ...  Iron (% DV)  \
# Beverage Info                                         ...
# Brewed Coffee - Grande-SBUX           0            1  ...            0
# Brewed Coffee - Tall-SBUX             0            0  ...            0
# Brewed Coffee - Venti-SBUX            0            1  ...            0
# Caffè Latte - 2% Milk-SBUX            9            6  ...            0
# Caffè Latte - 2% Milk-SBUX           14           10  ...            0
#
#                              Chol_to_C  Carb_to_C  F_to_C S_to_C  P_to_C  \
# Beverage Info
# Brewed Coffee - Grande-SBUX      0.00%    200.00%   0.00%  0.00%  20.00%
# Brewed Coffee - Tall-SBUX        0.00%    250.00%   0.00%  0.00%   0.00%
# Brewed Coffee - Venti-SBUX       0.00%    200.00%   0.00%  0.00%  20.00%
# Caffè Latte - 2% Milk-SBUX      10.00%     85.00%   0.00%  9.00%   6.00%
# Caffè Latte - 2% Milk-SBUX      10.00%     90.00%   0.00%  9.33%   6.67%
#
#                              A_to_C C_to_C Ca_to_C Fe_to_C
# Beverage Info
# Brewed Coffee - Grande-SBUX   0.00%  0.00%   0.00%   0.00%
# Brewed Coffee - Tall-SBUX     0.00%  0.00%   0.00%   0.00%
# Brewed Coffee - Venti-SBUX    0.00%  0.00%  40.00%   0.00%
# Caffè Latte - 2% Milk-SBUX   10.00%  0.00%  20.00%   0.00%
# Caffè Latte - 2% Milk-SBUX   10.00%  0.00%  20.00%   0.00%
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Data Visualizations

# %% [markdown]
# Options: line plot, bar charts for comparisons, histograms for distributions, or scatter plots for relationships.

# %%
# splitting dataframe into 2  parts to faciliate visualization:
midpoint = len(combined) // 2  
first_half = combined.iloc[:midpoint] 
second_half = combined.iloc[midpoint:]  

# needed more- splitting dataframe into 4 parts to faciliate visualization:
midpoint_first_half = len(first_half) // 2
first_half_part1 = first_half.iloc[:midpoint_first_half]
first_half_part2 = first_half.iloc[midpoint_first_half:]

midpoint_second_half = len(second_half) // 2
second_half_part1 = second_half.iloc[:midpoint_second_half]
second_half_part2 = second_half.iloc[midpoint_second_half:]

# %%
# decided to display nutrient ratios by food using line graph


# creating 4 subplots 
fig, axes = plt.subplots(2, 2, figsize=(16, 14), sharey=True)

# plotting Q1
first_half_part1.plot(ax=axes[0, 0], kind='line', marker='o', title='TBD')
axes[0, 0].set_xticks(range(len(first_half_part1.index)))
axes[0, 0].set_xticklabels(first_half_part1.index, rotation=65)
axes[0, 0].set_xlabel('TBD')
axes[0, 0].set_ylabel('TBD')

# plotting Q2
first_half_part2.plot(ax=axes[0, 1], kind='line', marker='o', title='TBD')
axes[0, 1].set_xticks(range(len(first_half_part2.index)))
axes[0, 1].set_xticklabels(first_half_part2.index, rotation=65)
axes[0, 1].set_xlabel('TBD')

# plotting Q3
second_half_part1.plot(ax=axes[1, 0], kind='line', marker='o', title='TBD')
axes[1, 0].set_xticks(range(len(second_half_part1.index)))
axes[1, 0].set_xticklabels(second_half_part1.index, rotation=65)
axes[1, 0].set_xlabel('TBD')
axes[1, 0].set_ylabel('TBD')

# plotting Q4
second_half_part2.plot(ax=axes[1, 1], kind='line', marker='o', title='TBD')
axes[1, 1].set_xticks(range(len(second_half_part2.index)))
axes[1, 1].set_xticklabels(second_half_part2.index, rotation=65)
axes[1, 1].set_xlabel('TBD')

# displaying plot
plt.suptitle('TBD')
plt.tight_layout()
plt.show()
